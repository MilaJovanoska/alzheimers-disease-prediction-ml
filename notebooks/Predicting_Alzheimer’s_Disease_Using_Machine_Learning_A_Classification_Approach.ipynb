# %% [markdown]
# ## 🖥️📚📖 **Предмет:** Машинско учење
# ## 📑📈🧪**Проект**
# ## 🧠⚕️🧬 **Наслов на проектот:**
# ### *Predicting Alzheimer’s Disease Using Machine Learning: A Classification Approach*

# %% [markdown]
# <div align="justify">
#
# <details open>
# <summary><h2>🧠 Што е Алцхајмерова болест?</h2></summary>
#
# **Алцхајмеровата болест (Alzheimer’s Disease)** е најчестиот облик на деменција и претставува хронична, прогресивна и неизлечива **невродегенеративна болест**. Болеста предизвикува прогресивна дегенерација и умирање на нервните клетки (неврони) во мозокот, што резултира со губење на меморијата, нарушено размислување, намалени говорни способности и неспособност за извршување на секојдневни активности.
# Со текот на времето, пациентот губи сè повеќе од неговите когнитивни функции, станува зависен од другите, и на крајот дури и основните телесни функции (како голтање и движење) се нарушуваат.
# Со цел подобро да го разбереме влијанието на болеста, потребно е да се запознаеме со когнитивните функции што таа ги нарушува
#
#
# ### 🧮 Што се когнитивни функции?
#
# **Когнитивните функции** се ментални процеси кои ни овозможуваат да перцепираме, учиме, паметиме, разбираме, донесуваме одлуки и комуницираме.
# Тие се основа на нашето секојдневно функционирање и вклучуваат:
#
# - **Меморија**: Способноста за складирање и повикување на информации.
# - **Внимание**: Фокусирање на релевантни стимули и информации.
# - **Јазик**: Разбирање и користење на говорот и пишаниот јазик.
# - **Извршни функции**: Планирање, организирање, решавање проблеми и флексибилност во размислувањето.
# - **Визуелно-просторна перцепција**: Разбирање на визуелни информации и просторни односи.
#
# Нарушувањата во овие функции можат значително да го отежнат секојдневниот живот на поединецот.
#
# Покрај разбирањето на когнитивните функции, важно е да се согледа и глобалното влијание на болеста.
#
#
# ### 📊 Глобални статистики
#
# Според податоци од Светската здравствена организација и други релевантни извори:
#
# - Во 2021 година, **57 милиони луѓе** ширум светот живееле со деменција, при што **Алцхајмеровата болест** е најчестата форма, одговорна за 60–70% од случаите.
# - Се предвидува дека до 2050 година, бројот на лица со деменција ќе достигне **139 милиони**.
# - Во САД, се проценува дека во 2025 година, **7.2 милиони** Американци на возраст од 65 и повеќе години ќе живеат со Алцхајмерова болест.
# - Болеста е **седма водечка причина за смртност** на глобално ниво и е една од главните причини за инвалидитет и зависност кај постарите лица.
#
#
# ### ⚠️ Влијание врз индивидуата и општеството
#
# Алцхајмеровата болест не влијае само на поединецот, туку има и значителни последици за семејствата, здравствениот систем и економијата. Болеста доведува до:
#
# - Зголемена потреба за нега и поддршка.
# - Финансиски трошоци за медицинска и социјална грижа.
# - Емоционален и физички товар за негувателите.
#
# Овие последици покажуваат дека Алцхајмеровата болест е не само медицински, туку и социјален и економски предизвик кој бара системски пристап.
# </details>
# </div>

# %% [markdown]
# <div align="justify">
# <details open>
# <summary><h2>🧬 Главни причинители на Алцхајмеровата болест</h2></summary>
#
# Иако точниот механизам што ја предизвикува Алцхајмеровата болест сè уште не е целосно објаснет, научната заедница има идентификувано неколку **главни фактори на ризик** кои придонесуваат за нејзиниот развој. Овие фактори можат да бидат **генетски, биолошки, животни или околински**.
#
#
#
# ### 🧬 1. Генетска предиспозиција
#
# Еден од најсилните генетски ризик-фактори за развој на Алцхајмерова болест е присуството на **APOE ε4 алелот** (Apolipoprotein E epsilon 4, варијанта на ген).
#
# - **APOE** е ген кој го кодира аполипопротеин E – протеин што помага во транспорт на липиди (масти) во крвта.
# - Луѓето кои имаат една копија од **ε4** имаат 2–3 пати повисок ризик.
# - Луѓето со **две копии** (една од мајката и една од таткото) имаат до **12 пати повисок ризик** за развој на болеста.
#
# > 🔍 Важно: Присуството на APOE ε4 **не значи сигурно** дека некој ќе ја развие болеста – тоа само ја зголемува веројатноста.
#
#
# ### 👴 2. Возраст
#
# - Возраста е **најсилниот неконтролирачки фактор**.
# - Над 65 години, ризикот се удвојува приближно на секои 5 години.
# - Над 85 години, речиси **1 од 3 лица** има некаква форма на деменција.
#
#
# ### 👨‍👩‍👧‍👦 3. Фамилијарна историја
#
# - Лица со роднина од прв степен (родител или брат/сестра) со Алцхајмер имаат **повисок ризик**, особено ако болеста се јавила кај роднината на помлада возраст.
# - Комбинацијата на **фамилијарна историја + APOE ε4** го зголемува ризикот експоненцијално.
#
# Сепак, фамилијарната историја не гарантира развој на болеста, туку само ја зголемува веројатноста.
#
#
# ### ❤️ 4. Кардиоваскуларно здравје
#
# Алцхајмерот сè почесто се смета за **метаболичка и васкуларна болест**. Фактори како:
#
# - висок крвен притисок (хипертензија)
# - висок шеќер (дијабетес тип 2)
# - висок холестерол
# - дебелина
#
# …имаат **директна врска** со зголемен ризик од дегенерација на мозочни клетки.
#
#
# ### 🍷 5. Начин на живот и околина
#
# Неконтролирани фактори од секојдневниот живот, кои исто така влијаат:
#
# - Пушење и прекумерна употреба на алкохол
# - Недостаток на физичка активност
# - Недостаток на ментална стимулација
# - Лоша исхрана (богата со заситени масти и шеќери)
# - Слаба социјална интеракција
# - Изложеност на токсини (на пример: загаден воздух, метали, пестициди)
#
# Овие фактори, поединечно или во комбинација, значително можат да го зголемат ризикот од појава или напредување на Алцхајмеровата болест
# </details>
# </div>

# %% [markdown]
# <div align="justify">
# <details open>
# <summary><h2>👵 Кога и кај кого се јавува Алцхајмеровата болест?</h2></summary>
#
# Алцхајмеровата болест може да се јави кај различни групи луѓе, но најчесто е поврзана со процесот на стареење. Таа **не е нормален дел од стареењето**, но возраста е еден од најсилните ризик-фактори за нејзино појавување.
#
#
# ### 📆 Возраст на појава
#
# - **Late-onset Alzheimer’s disease** – најчеста форма (околу 95% од случаите), започнува по **65-та година**.
# - **Early-onset Alzheimer’s disease** – ретка форма (околу 5% од случаите), која започнува меѓу **40 и 60 години**, често генетски предизвикана од мутација во гени како **APP**, **PSEN1** и **PSEN2**.
#
# Овие гени се одговорни за продукција на **β-амилоиден протеин**, кој во случај на мутација се натрупува во мозокот и ја предизвикува дегенерацијата на невроните уште во средни години.
# Препознавањето на возраста на појава и генетските ризици е од клучно значење за навремена дијагноза и интервенција
#
# ### 🧬 Демографски карактеристики и ризични групи
#
# - **Жени** имаат нешто поголем ризик – делумно поради тоа што живеат подолго, но и поради хормонални и генетски фактори.
# - Лица со **ниско образовно ниво** имаат повисока зачестеност – најверојатно поради помала когнитивна резерва (способност на мозокот да компензира при губење на функции).
# - **Афроамериканци и латиноамериканци** во САД имаат повисок ризик, што е поврзано и со нееднаквости во здравството и преваленцијата на хронични болести.
#
# Препознавањето на овие демографски ризици овозможува насочени интервенции и стратегии за рана детекција и поддршка
#
#
# ### 🧠 Продромална фаза – Можни рани знаци
#
# Во некои случаи, Алцхајмеровата болест започнува со **блага когнитивна нарушеност (MCI – Mild Cognitive Impairment)**, која:
# - не е доволно сериозна за да влијае значајно на секојдневниот живот,
# - но може да прерасне во Алцхајмер по неколку години.
#
# Пациенти со **MCI + APOE ε4 ген** имаат многу поголема шанса да развијат Алцхајмер.
#
# Затоа, внимателното следење на пациентите со MCI е клучно за рана интервенција и потенцијално одложување на прогресијата.
#
# </details>
# </div>

# %% [markdown]
# <div align="justify">
# <details open>
# <summary><h2>🧪 Механизам на болеста – Што се случува во мозокот?</h2></summary>
#
# Алцхајмеровата болест се карактеризира со **прогресивна дегенерација на мозочните клетки**, особено оние кои се одговорни за меморија, мислење и одлучување. Главните патолошки промени во мозокот на пациентите со Алцхајмер се поврзани со **две главни структури**:
#
#
# ### 🧱 1. Бета-амилоидни плаки (β-amyloid plaques)
#
# - Бета-амилоид е протеин што во нормални услови се распаѓа и елиминира.
# - Кај пациенти со Алцхајмер, овие протеини се натрупуваат **надвор од невроните**, формирајќи **лепливи наслаги** (плаки).
# - Плаките го попречуваат нормалниот пренос на сигнали меѓу мозочните клетки и предизвикуваат **воспаление и оштетување**.
#
#
# ### 🧪 2. Тау протеин и неврофибриларни заплети (Neurofibrillary tangles)
#
# - **Тау** е протеин кој нормално помага во стабилизација на микротубули (внатрешни „патишта“ на невроните).
# - Кај Алцхајмер, тау се **абнормално фосфорилира**, што доведува до **внатрешни заплети** во клетките.
# - Овие заплети го попречуваат нормалниот транспорт на хранливи материи и предизвикуваат **смрт на невроните**.
#
#
# ### 🧠 Прогресивна дегенерација
#
# - Загубата на синапси (врски меѓу неврони) и умирање на клетки почнува **во хипокампусот** – регионот одговорен за меморијата.
# - Со тек на време, дегенерацијата се шири и во други делови од мозокот, вклучително и **кората (cerebral cortex)**.
# - На крајот, мозокот значајно се **смалува (атрофира)**, особено во регии клучни за мислење, однесување и самосвест.
#
# Разбирањето на овие механизми е клучно за развој на нови дијагностички методи и третмани кои таргетираат овие патолошки процеси.
#
# </details>
# </div>

# %% [markdown]
# <div align="justify">
# <details open>
# <summary><h2>🛡️ Како може да се спречи Алцхајмеровата болест?</h2></summary>
#
# Иако **Алцхајмеровата болест не може целосно да се спречи**, сè повеќе истражувања покажуваат дека соодветен начин на живот може значително да го **намали ризикот или да го одложи нејзиното појавување**. Станува збор за холистички пристап – кој вклучува телесно, ментално и социјално здравје.
#
#
# ### 🧠 1. Одржување на ментална активност
#
# Мозокот, исто како мускулите, се зајакнува со вежбање. Активности кои ја стимулираат когницијата, како:
#
# - читање, пишување, учење нови јазици,
# - решавање крстозбори и логички игри (судоку, шах),
# - свирење инструмент или креативно хоби,
#
# …придонесуваат за **поголема когнитивна резерва**, која помага во одложување на симптомите.
#
#
# ### 🏃‍♂️ 2. Редовна физичка активност
#
# Телесната активност:
#
# - ја подобрува циркулацијата во мозокот,
# - ги намалува воспалителните процеси,
# - ја поттикнува неуропластичноста (способноста на мозокот да се прилагодува).
#
# Светската здравствена организација препорачува **најмалку 150 минути неделно** умерена физичка активност (брзо одење, пливање, танцување итн.). Редовното вежбање не само што придонесува за физичко здравје, туку е клучно и за зачувување на когнитивните функции со текот на годините.
#
#
# ### 🥗 3. Балансирана и хранлива исхрана
#
# Диетите како **Mediterranean diet** и **MIND diet (Mediterranean-DASH Intervention for Neurodegenerative Delay)** се поврзани со понизок ризик од деменција:
#
# - Висок внес на овошје, зеленчук, јаткасти плодови, маслиново масло, риба.
# - Намален внес на заситени масти, црвено месо и рафинирани шеќери.
# - Заменување на пржени и преработени јадења со свежа и варена храна.
#
#
# ### 💓 4. Контрола на ризик-фактори
#
# Кардиоваскуларното здравје е тесно поврзано со когнитивното. Спречувањето или управувањето со:
#
# - висок крвен притисок,
# - дијабетес тип 2,
# - хиперхолестеролемија,
# - дебелина,
#
# …може да го **заштити мозокот од дегенеративни промени**.
#
#
# ### 🛌 5. Квалитетен и доволен сон
#
# - За време на длабок сон, мозокот ги прочистува токсичните бета-амилоидни наслаги.
# - Недостаток на сон или нарушувања како **опструктивна апнеа** се поврзани со повисок ризик.
# - Препорака: **7–9 часа квалитетен сон секоја ноќ**.
#
#
# ### 👥 6. Социјална ангажираност и емоционално здравје
#
# - Луѓето кои остануваат активни во заедницата, имаат посилна ментална резистентност.
# - Осаменоста и депресијата се исто така ризик-фактори.
# - Активности: волонтирање, семејни средби, групни хобиа.
#
# Овие активности помагаат да се намали ризикот од когнитивен пад и да се одржи добро ментално здравје со текот на годините
# </details>
# </div>

# %% [markdown]
# <div align="justify">
# <details open>
# <summary><h2>💊 Третман и нега кај Алцхајмеровата болест</h2></summary>
#
# Во моментов **нема лек** што целосно ја излекува Алцхајмеровата болест. Но, постојат **начини за забавување на болеста**, **намалување на симптомите** и **помош на пациентите** да живеат поквалитетно.
#
#
# ### 🧪 Лекови
#
# Се користат неколку видови лекови, во зависност од симптомите и фазата на болеста:
#
# - **За подобрување на памтењето**
#   → *Donepezil* (Aricept)
#
# - **За подобрување на комуникацијата меѓу мозочните клетки**
#   → *Rivastigmine* (Exelon), *Galantamine* (Razadyne)
#
# - **За намалување на некои симптоми, особено во подоцнежна фаза**
#   → *Memantine* (Namenda)
#
#
# ### 🧠 Поддржувачки методи и активности
#
# - **Когнитивна стимулација:** Вежби за мозокот како загатки, игри со зборови, судоку или шах можат да помогнат во одржување на менталната активност и одложување на влошувањето на когнитивните функции.
# - **Редовна дневна рутина:** Утврдената рутина создава чувство на сигурност и стабилност кај пациентите, го намалува стресот и ги ублажува симптомите на збунетост или агресија.
# - **Безбедна околина:** Адаптирање на домот за да се избегнат повреди (отстранување на непотребни предмети, користење заштитни средства во бањата, обезбедување добра осветленост).
# - **Психолошка и емоционална поддршка:** Вклучување на пациентот во пријатни активности, како музика, цртање или други хобија, може да помогне во подобрување на расположението.
# - **Поддршка од блиски луѓе:** Охрабрување на социјална интеракција со семејството и пријателите помага да се намалат чувствата на осаменост и депресија.
#
#
# ### 👪 Грижа од семејството
#
# - **Важност на негувателите:** Негувателите се клучни за секојдневната грижа, но нивната физичка и психичка благосостојба е исто така важна за континуирана и квалитетна грижа.
# - **Поддршка за негувателите:** Потребна е емоционална и практична поддршка за негувателите, бидејќи грижата за пациент со Алцхајмерова болест може да биде исцрпувачка и стресна.
# - **Едукација:** Обука и информации за текот на болеста, техники за комуникација и справување со тешки ситуации можат значително да ја олеснат грижата.
# - **Групи за советување и помош:** Учество во групи за поддршка со други негуватели нуди можност за споделување искуства, совети и добивање психолошка поддршка.
# - **Распределување на грижата:** Вклучување на повеќе членови од семејството или користење професионални услуги за да се избегне прегорување на негувателите.
#
# Третманот на Алцхајмеровата болест бара мултидисциплинарен пристап кој комбинира медицинска терапија, психолошка поддршка и активна улога на семејството и заедницата.
#
# </details>
# </div>

# %% [markdown]
# <div align="justify">
# <details>
# <summary><h2>🧾Заклучок од теоретскиот дел</h2></summary>
#
#
# Алцхајмеровата болест претставува една од најсериозните закани за јавното здравје во 21-от век. Како хронично, прогресивно и неизлечиво невродегенеративно заболување, таа значително влијае не само на засегнатите лица, туку и на нивните семејства, негуватели и целиот здравствен систем.
#
# Денес откривме дека болеста има сложен и мултифакторски карактер. Најзначајните причинители вклучуваат генетска предиспозиција, стареење, кардиоваскуларни нарушувања и фактори од начинот на живот. Разбравме дека болеста не е нормален дел од стареењето и дека може да се појави дури и кај помлади лица со специфични генетски мутации.
#
# Преку анализа на механизмите во мозокот, видовме како натрупувањето на амилоидни плаки и тау-протеини води до губење на синаптичките врски и умирање на нервните клетки, што резултира со постепена когнитивна дегенерација.
#
# Иако во моментов не постои целосно лекување, постојат терапии кои можат да го забават прогресот на болеста и да го подобрат квалитетот на живот. Истовремено, превентивните мерки како здрав начин на живот, ментална стимулација и контрола на хронични болести можат значително да го намалат ризикот.
#
# Овој проект има за цел, со помош на техники на машинско учење, да развие модел за **класификација на ризикот од Алцхајмерова болест**, базиран на реални медицински и демографски податоци. Раната детекција и разбирањето на клучните индикатори ќе можат да придонесат кон подобра дијагностика, интервенција и поддршка за пациентите.
#
# </details>
# </div>

# %% [markdown]
# <div align="justify">
# <details open>
# <summary><h1>📊 Опис на податочното множество</h1></summary>
#
# Податочното множество Alzheimer’s Disease Dataset содржи здравствени информации за **2.149 пациенти**, секој со единствен идентификатор во опсег од **4751 до 6900**. Вклучува демографски податоци, животни навики, медицинска историја, клинички мерења, когнитивни и функционални проценки, симптоми и дијагноза на **Алцхајмерова болест**.
#
# Идеално е за истражувачи и научници по податоци кои сакаат да ги истражат факторите поврзани со Алцхајмеровата болест, да развијат предиктивни модели и да спроведат статистички анализи.
#
#
# ## 🗂️ Структура на податоците
#
# ### 🆔 Информации за пациентот
# - **PatientID**: Единствен идентификатор за секој пациент (4751–6900)
#
# ### 🧑‍🤝‍🧑 Демографски податоци
# - **Age**: Возраст (60–90 години)
#
# - **Gender**: Пол (0 = Машки, 1 = Женски)
#
# - **Ethnicity**: Етничка припадност (0 = Белец, 1 = Афроамериканец, 2 = Азиец, 3 = Друго)
#
# - **EducationLevel**: Степен на завршено образование
#   (0 = Без формално образование, 1 = Средно училиште, 2 = Додипломски студии, 3 = Постдипломски студии – магистер или докторски студии)
#
# ### 🏃 Животни навики
# - **BMI**: Индекс на телесна маса (15–40)
#
# - **Smoking**: Пушење (0 = Не, 1 = Да)
#
# - **AlcoholConsumption**: Неделна консумација на алкохол (0–20 единици)
#
# - **PhysicalActivity**: Неделна физичка активност (0–10 часа)
#
# - **DietQuality**: Квалитет на исхрана (0–10)
#
# - **SleepQuality**: Квалитет на спиење (4–10)
#
# ### 🩺 Медицинска историја
# - **FamilyHistoryAlzheimers**: Семејна историја на Алцхајмер (0 = Не, 1 = Да)
#
# - **CardiovascularDisease**: Присуство на кардиоваскуларни болести
#   (0 = Не, 1 = Да)
#
# - **Diabetes**: Присуство на дијабетес
#   (0 = Не, 1 = Да)
#
# - **Depression**: Присуство на дијагностицирана депресија
#   (0 = Не, 1 = Да)
#
# - **HeadInjury**: Историја на повреда на глава
#   (0 = Не, 1 = Да)
#
# - **Hypertension**: Присуство на висок крвен притисок (хипертензија)
#   (0 = Не, 1 = Да)
#
#
# ### ⚕️ Клинички мерења
#
# - **SystolicBP**: Систолен крвен притисок (горна вредност)
#   (опсег: 90 до 180 mmHg)
#
# - **DiastolicBP**: Дијастолен крвен притисок (долна вредност)
#   (опсег: 60 до 120 mmHg)
#
# - **CholesterolTotal**: Вкупно ниво на холестерол
#   (опсег: 150 до 300 mg/dL)
#
# - **CholesterolLDL**: Ниво на LDL (лош холестерол – липопротеини со мала густина)
#   (опсег: 50 до 200 mg/dL)
#
# - **CholesterolHDL**: Ниво на HDL (добар холестерол – липопротеини со висока густина)
#   (опсег: 20 до 100 mg/dL)
#
# - **CholesterolTriglycerides**: Ниво на триглицериди
#   (опсег: 50 до 400 mg/dL)
#
# ### 🧠 Когнитивни и функционални проценки
#
# - **MMSE**: Оценка од Mini-Mental State Examination
#   (опсег: 0 до 30; пониски вредности означуваат поголемо  когнитивно оштетување)
#
# - **FunctionalAssessment**: Оценка на функционалност
#   (опсег: 0 до 10; пониски вредности означуваат поголем степен на попреченост)
#
# - **MemoryComplaints**: Присуство на жалби за меморија
#   (0 = Не, 1 = Да)
#
# - **BehavioralProblems**: Присуство на проблеми во однесувањето
#   (0 = Не, 1 = Да)
#
# - **ADL (Activities of Daily Living)**: Способност за извршување секојдневни активности
#   (опсег: 0 до 10; пониски вредности означуваат поголема неспособност)
#
#
# ### ⚠️ Симптоми
#
# - **Confusion**: Присуство на конфузија
#   (0 = Не, 1 = Да)
#
# - **Disorientation**: Присуство на дезориентација
#   (0 = Не, 1 = Да)
#
# - **PersonalityChanges**: Промени во личноста
#   (0 = Не, 1 = Да)
#
# - **DifficultyCompletingTasks**: Потешкотии во завршување на задачи
#   (0 = Не, 1 = Да)
#
# - **Forgetfulness**: Присуство на заборавеност
#   (0 = Не, 1 = Да)
#
#
# ### 🧾 Дијагностички информации
#
# - **Diagnosis**: Дијагноза за Алцхајмерова болест
#   (0 = Не, 1 = Да)
#
#
# ### 👨‍⚕️ Информации за докторот
#
# - **DoctorInCharge**: Колона со доверлива информација за докторот што го води случајот
#   (сите вредности се "XXXConfid")
#
# ## 🧩 Заклучок
#
# Ова податочно множество нуди длабински увид во факторите поврзани со Алцхајмеровата болест, вклучувајќи демографски податоци, начин на живот, медицинска историја, клинички мерења, когнитивни и функционални проценки и симптоми. Идеално е за развој на предиктивни модели, статистичка анализа и истражување на комплексните поврзаности кај оваа болест.
#
# ##🔗 Извор на податочното множество Alzheimer’s Disease Dataset:
# [Alzheimer’s Disease Dataset на Kaggle](https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset)
#
# </details>
# </div>

# %%
# 📦 Основни библиотеки за работа со податоци и математика
import pandas as pd
import numpy as np

# 📊 Библиотеки за визуелизација на податоци
import matplotlib.pyplot as plt
import seaborn as sns

# ⚙️ Предобработка на податоци и избалансирање на класи
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# 🤖 Класични модели за машинско учење
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# 🔍 Поделба на податоци и оптимизација на хиперпараметри
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV

# 📝 Метрики за евалуација на модели и анализа на перформанси
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight

# 🧬 Алати за избор на најрелевантни атрибути (feature selection)
from sklearn.feature_selection import mutual_info_classif, RFE

# 🧠 Deep learning модели со TensorFlow/Keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# 📦 Random Forest класификатор за градење на енсамбл модели базирани на дрва
from sklearn.ensemble import RandomForestClassifier

# %%
# Вчитување на податоците за Алцхајмерова болест во DataFrame
alzheimers_data = pd.read_csv("alzheimers_disease_data.csv")

# %%
# Прикажување на сите колони
pd.set_option('display.max_columns', None)

# %%
# Приказ на првите 5 редови од податочното множество
alzheimers_data.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0           13.297218          6.327112     1.347214      9.025679
# 1            4.542524          7.619885     0.518767      7.151293
# 2           19.555085          7.844988     1.826335      9.673574
# 3           12.209266          8.428001     7.435604      8.392554
# 4           18.454356          6.310461     0.795498      5.597238
#
#    FamilyHistoryAlzheimers  CardiovascularDisease  Diabetes  Depression  \
# ...

# %%
# Приказ на првите 10 редови од податочното множество
alzheimers_data.head(10)
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
# 5       4756   86       1          1               1  30.626886        0
# 6       4757   68       0          3               2  38.387622        1
# 7       4758   75       0          0               1  18.776009        0
# 8       4759   72       1          1               0  27.833188        0
# 9       4760   87       0          0               0  35.456302        1
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 0           13.297218          6.327112     1.347214      9.025679
# ...

# %%
# Приказ на последните 5 редови од податочното множество
alzheimers_data.tail()
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 2144            1.561126          4.049964     6.555306      7.535540
# 2145           18.767261          1.360667     2.904662      8.555256
# 2146            4.594670          9.886002     8.120025      5.769464
# 2147            8.674505          6.354282     1.263427      8.322874
# 2148            7.890703          6.570993     7.941404      9.878711
#
#       FamilyHistoryAlzheimers  CardiovascularDisease  Diabetes  Depression  \
# ...

# %%
# Приказ на последните 10 редови од податочното множество
alzheimers_data.tail(10)
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 2139       6890   68       0          1               0  17.828965        0
# 2140       6891   89       0          1               2  34.422419        0
# 2141       6892   72       0          0               2  21.600144        0
# 2142       6893   88       0          0               0  20.097600        0
# 2143       6894   66       1          2               1  32.013806        1
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# ...

# %%
# Приказ на случајно избран ред од податочното множество
alzheimers_data.sample()
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 1748       6499   82       0          3               0  23.234745        1
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 1748            9.185361          7.159601     1.131272      4.613668
#
#       FamilyHistoryAlzheimers  CardiovascularDisease  Diabetes  Depression  \
# 1748                        0                      1         0           0
#
#       HeadInjury  Hypertension  SystolicBP  DiastolicBP  CholesterolTotal  \
# 1748           0             0         131           91        186.358481
#
#       CholesterolLDL  CholesterolHDL  CholesterolTriglycerides      MMSE  \
# 1748      195.585093       29.153316                368.836424  6.488268
#
#       FunctionalAssessment  MemoryComplaints  BehavioralProblems      ADL  \
# 1748              8.109405                 0                   0  8.98709
#
#       Confusion  Disorientation  PersonalityChanges  \
# ...

# %%
# Приказ на 5 случајно избрани редови од податочното множество
alzheimers_data.sample(5)
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 265        5016   82       1          2               2  26.130212        1
# 998        5749   71       0          0               1  36.571735        1
# 909        5660   71       0          0               2  37.462553        0
# 1804       6555   77       1          0               0  35.577987        1
# 774        5525   76       0          0               1  35.881290        1
#
#       AlcoholConsumption  PhysicalActivity  DietQuality  SleepQuality  \
# 265            15.167105          2.387059     9.197977      9.296660
# 998            11.236121          2.535219     6.444034      7.266740
# 909             6.091720          5.016604     8.700893      6.835320
# 1804           18.940150          6.311665     7.155175      9.484200
# 774            16.294793          7.118326     0.380311      4.236557
#
#       FamilyHistoryAlzheimers  CardiovascularDisease  Diabetes  Depression  \
# ...

# %%
# Приказ на основни информации за колоните, типот на податоци и бројот на вредности кои недостасуваат
alzheimers_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
# 📏 Приказ на формата на податочното множество (број на редови и колони)
print(f"Формата на податочното множество (редови, колони): {alzheimers_data.shape}")
# Out:
# Формата на податочното множество (редови, колони): (2149, 35)

# %%
# Податочното множество содржи 2149 записи (редови) и 35 променливи (колони).
# Секој ред претставува еден пациент или примерок, додека секоја колона претставува одредена
# карактеристика поврзана со демографија, клинички податоци или други фактори поврзани со Алцхајмеровата болест.

# %%
# Проверка и сортирање на бројот на недостасувачки вредности по колона
print("Број на недостасувачки вредности по колона (сортирано опаѓачки):")
print(alzheimers_data.isnull().sum().sort_values(ascending=False))
# Out:
# Број на недостасувачки вредности по колона (сортирано опаѓачки):
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# ...

# %%
# Во податочното множество нема недостасувачки вредности, бидејќи секоја колона има нула (0)
# вредности што недостасуваат според резултатот од isnull().sum().

# %%
print("Број на пациенти по класа во колоната 'Diagnosis':")
print(alzheimers_data['Diagnosis'].value_counts())
# Out:
# Број на пациенти по класа во колоната 'Diagnosis':
# Diagnosis
# 0    1389
# 1     760
# Name: count, dtype: int64

# %%
print("Процентуална застапеност на класите во 'Diagnosis':")
print(round((alzheimers_data['Diagnosis'].value_counts() / len(alzheimers_data)) * 100, 2))
# Out:
# Процентуална застапеност на класите во 'Diagnosis':
# Diagnosis
# 0    64.63
# 1    35.37
# Name: count, dtype: float64

# %%
# Податочното множество е умерено неурамнотежено.
# Имаме 1389 пациенти без дијагностицирана болест (класа 0) и 760 пациенти со дијагноза (класа 1).
# Ова значи дека класа 0 е застапена со околу 64.63%, а класа 1 со околу 35.37%, што може да влијае врз точноста на моделите ако не се преземат мерки за баланс на податочното множество.

# %%
# Креирање на фигура со 2 подграфици, странично поставени
plt.figure(figsize=(14, 6))

# Хистограм со KDE за пациентите без Алцхајмер (класа 0)
plt.subplot(1, 2, 1)
sns.histplot(
    alzheimers_data[alzheimers_data["Diagnosis"] == 0]["FunctionalAssessment"],
    bins=10, kde=True, color='skyblue', edgecolor='black'
)
plt.title("FunctionalAssessment - Класа 0 (Без Алцхајмер)")
plt.xlabel("Оценка на функционалност")
plt.ylabel("Број на пациенти")

# Хистограм со KDE за пациентите со Алцхајмер (класа 1)
plt.subplot(1, 2, 2)
sns.histplot(
    alzheimers_data[alzheimers_data["Diagnosis"] == 1]["FunctionalAssessment"],
    bins=10, kde=True, color='salmon', edgecolor='black'
)
plt.title("FunctionalAssessment - Класа 1 (Со Алцхајмер)")
plt.xlabel("Оценка на функционалност")
plt.ylabel("Број на пациенти")

# Автоматско прилагодување на растојанијата меѓу подграфиците
plt.tight_layout()

# Приказ на графиконите
plt.show()

# %%
# Заклучок за променливата FunctionalAssessment (Оценка на функционалност):
#
# Анализата на хистограмите покажува јасна разлика помеѓу двете класи.
# Кај пациентите без Алцхајмерова болест (Diagnosis = 0), оценките за FunctionalAssessment
# се претежно високи (7 до 10), што укажува на добра самостојност и способност за извршување секојдневни активности.
#
# Кај пациентите со Алцхајмерова болест (Diagnosis = 1), вредностите се концентрирани во пониски оценки (0 до 4),
# што значи дека имаат намалена функционална способност и се зависни од поддршка.
#
# Оваа карактеристика е од голема важност за класификација бидејќи директно одразува
# последици од прогресијата на болеста. FunctionalAssessment треба да биде земена предвид
# како клучен индикатор при моделирање и анализа.

# %%
# Креирање на две споредни графики со заедничка Y-оска
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Хистограм со KDE за пациенти без Алцхајмер (класа 0)
sns.histplot(
    data=alzheimers_data[alzheimers_data['Diagnosis'] == 0],
    x='ADL', kde=True, bins=10, color='skyblue',
    stat='count', ax=axes[0], edgecolor='black'
)
axes[0].set_title("ADL - Класа 0 (Без Алцхајмер)")
axes[0].set_xlabel("Оценка на ADL")
axes[0].set_ylabel("Број на пациенти")
axes[0].grid(True)

# Хистограм со KDE за пациенти со Алцхајмер (класа 1)
sns.histplot(
    data=alzheimers_data[alzheimers_data['Diagnosis'] == 1],
    x='ADL', kde=True, bins=10, color='salmon',
    stat='count', ax=axes[1], edgecolor='black'
)
axes[1].set_title("ADL - Класа 1 (Со Алцхајмер)")
axes[1].set_xlabel("Оценка на ADL")
axes[1].set_ylabel("Број на пациенти")  # прикажување и на левата Y-оска
axes[1].tick_params(left=True, labelleft=True)
axes[1].grid(True)

# Автоматско прилагодување на распоредот меѓу графиките
plt.tight_layout()
plt.show()

# %%
# Заклучок за променливата ADL (Activities of Daily Living):
#
# Анализата на хистограмите покажува јасна разлика помеѓу двете класи.
# Пациентите без Алцхајмерова болест (Diagnosis = 0) имаат високи оценки на ADL (7–10),
# што укажува на способност за самостојно извршување на секојдневни активности.
#
# Напротив, кај пациентите со Алцхајмер (Diagnosis = 1), оценките се концентрирани во пониските вредности (0–4),
# што укажува на сериозни функционални ограничувања и зависност од поддршка.
#
# Променливата ADL е силен предиктор и треба да биде вклучена во моделите за класификација,
# бидејќи на информативен начин ја одразува состојбата на пациентот.

# %%
# Креирање на две странични графики за MMSE вредностите, поделени по дијагноза
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

# Хистограм со KDE за пациенти без Алцхајмер (класа 0)
sns.histplot(
    data=alzheimers_data[alzheimers_data['Diagnosis'] == 0],
    x='MMSE', kde=True, bins=10, color='skyblue',
    stat='count', ax=axes[0], edgecolor='black'
)
axes[0].set_title("MMSE - Класа 0 (Без Алцхајмер)")
axes[0].set_xlabel("Оценка на MMSE")
axes[0].set_ylabel("Број на пациенти")
axes[0].grid(True)

# Хистограм со KDE за пациенти со Алцхајмер (класа 1)
sns.histplot(
    data=alzheimers_data[alzheimers_data['Diagnosis'] == 1],
    x='MMSE', kde=True, bins=10, color='salmon',
    stat='count', ax=axes[1], edgecolor='black'
)
axes[1].set_title("MMSE - Класа 1 (Со Алцхајмер)")
axes[1].set_xlabel("Оценка на MMSE")
axes[1].set_ylabel("Број на пациенти")
axes[1].tick_params(left=True, labelleft=True)
axes[1].grid(True)

# Автоматско прилагодување на распоредот
plt.tight_layout()
plt.show()

# %%
# Заклучок за променливата MMSE (Mini-Mental State Examination):
#
# Променливата MMSE мери когнитивни способности, при што повисоките оценки значат подобро когнитивно здравје.
# Кај пациентите без Алцхајмер (Diagnosis = 0), оценките се претежно високи (над 20), што укажува на добро когнитивно функционирање.
#
# Кај пациентите со Алцхајмер (Diagnosis = 1), оценките се распоредени во пониските интервали (0–15), што укажува на
# сериозно когнитивно оштетување.
#
# Распределбата покажува дека MMSE е многу силен индикатор за присуство на Алцхајмерова болест и треба да биде
# вклучен во сите модели за класификација.

# %%
# Креирање на фигура со 2 подграфика еден до друг и заедничка Y-оска
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

# Бар график за пациенти без Алцхајмер (класа 0)
sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 0],
              x='MemoryComplaints', palette='Blues', ax=axes[0])

axes[0].set_title('Memory Complaints - Класа 0 (Без Алцхајмер)')
axes[0].set_xlabel('Memory Complaints')
axes[0].set_ylabel('Број на пациенти')
axes[0].set_xticks([0, 1])
axes[0].set_xticklabels(['Нема', 'Има'])

# Бар график за пациенти со Алцхајмер (класа 1)
sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 1],
              x='MemoryComplaints', palette='Reds', ax=axes[1])
axes[1].set_title('Memory Complaints - Класа 0 (Со Алцхајмер)')
axes[1].set_xlabel('Memory Complaints')
axes[1].set_ylabel('')
axes[1].set_xticks([0, 1])
axes[1].set_xticklabels(['Нема', 'Има'])

# Автоматско прилагодување на распоредот
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-39-1735583939.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 0],
# /tmp/ipython-input-39-1735583939.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 1],

# %%
# Заклучок за променливата MemoryComplaints (Жалби за меморија):
#
# Променливата MemoryComplaints е бинарна (0 = Нема жалби, 1 = Има жалби).
# Графикот покажува дека кај пациентите без Алцхајмер (Diagnosis = 0), огромно мнозинство немаат жалби за меморија.
#
# Кај пациентите со Алцхајмер (Diagnosis = 1), бројот на пациенти кои имаат жалби за меморија е значително поголем
# во однос на класата 0, иако не е апсолутно доминантен.
#
# Ова покажува дека присуството на жалби за меморија е релативно добар индикатор за Алцхајмерова болест,
# но самостојно не е доволно за класификација – треба да се комбинира со други фактори.

# %%
# Креирање на фигура со две графики една до друга со заедничка Y-оска
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

# Бар график за пациенти без Алцхајмер (класа 0)
sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 0],
              x='Confusion', palette='Blues', ax=axes[0])
axes[0].set_title('Confusion - Класа 0 (Без Алцхајмер)')
axes[0].set_xlabel('Конфузија')
axes[0].set_ylabel('Број на пациенти')
axes[0].set_xticks([0, 1])
axes[0].set_xticklabels(['Нема', 'Има'])
axes[0].grid(True)

# Бар график за пациенти со Алцхајмер (класа 1)
sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 1],
              x='Confusion', palette='Reds', ax=axes[1])
axes[1].set_title('Confusion - Класа 1 (Со Алцхајмер)')
axes[1].set_xlabel('Конфузија')
axes[1].set_ylabel('')
axes[1].set_xticks([0, 1])
axes[1].set_xticklabels(['Нема', 'Има'])
axes[1].grid(True)

# Автоматско прилагодување на распоредот на елементите
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-41-582086007.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 0],
# /tmp/ipython-input-41-582086007.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=alzheimers_data[alzheimers_data['Diagnosis'] == 1],

# %%
# Заклучок за променливата Confusion (Конфузија):
#
# Променливата Confusion е бинарна: 0 = Нема конфузија, 1 = Има конфузија.
#
# Кај пациентите без Алцхајмерова болест (Diagnosis = 0), повеќето пациенти немаат конфузија,
# што е очекувано за когнитивно здрави лица. Само мал број пријавуваат конфузија.
#
# Кај пациентите со Алцхајмер (Diagnosis = 1), процентот на пациенти со конфузија е значително поголем,
# што укажува дека конфузијата е релативно чест симптом кај оваа болест.
#
# Сепак, не е присутна кај сите пациенти со Алцхајмер, па затоа Confusion не може да се користи самостојно
# како дијагностички индикатор. Нејзината сила доаѓа кога се комбинира со други симптоми,
# како што се ADL, MMSE, MemoryComplaints и FunctionalAssessment.

# %%
# Креирање на boxplot за споредба на MMSE (Mini-Mental State Examination) вредности по дијагноза
plt.figure(figsize=(8, 6))
sns.boxplot(x='Diagnosis', y='MMSE', data=alzheimers_data, palette=['skyblue', 'salmon'])

# Додавање на наслов и оски
plt.title('Boxplot на MMSE според дијагноза')
plt.xlabel('Дијагноза (0 = Без Алцхајмер, 1 = Со Алцхајмер)')
plt.ylabel('MMSE (Mini-Mental State Examination)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-43-1342423725.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Diagnosis', y='MMSE', data=alzheimers_data, palette=['skyblue', 'salmon'])

# %%
# Заклучок за променливата MMSE (Mini-Mental State Examination):
#
# Boxplot визуелизацијата покажува јасна разлика во дистрибуцијата на MMSE оценките помеѓу двете класи.
#
# Кај пациентите без Алцхајмер (Diagnosis = 0), медијаната е значително повисока (околу 18),
# и распоредот е поширок, со голем број пациенти кои имаат високи когнитивни способности (25+).
#
# Кај пациентите со Алцхајмер (Diagnosis = 1), медијаната е поместена надолу (околу 12),
# што укажува на послаб ментален капацитет. Покрај тоа, целата дистрибуција е пониско концентрирана,
# што значи дека повеќето пациенти имаат значајно нарушена когнитивна функција.
#
# Оваа променлива е еден од најсилните индикатори за дијагноза на Алцхајмерова болест
# и мора да биде вклучена во секој класификациски модел.

# %%
# Креирање на boxplot за споредба на ADL (Activities of Daily Living) вредности по дијагноза
plt.figure(figsize=(8, 6))
sns.boxplot(x='Diagnosis', y='ADL', data=alzheimers_data, palette=['skyblue', 'salmon'])

# Додавање на наслов и означување на оски
plt.title('Boxplot на ADL според дијагноза')
plt.xlabel('Дијагноза (0 = Без Алцхајмер, 1 = Со Алцхајмер)')
plt.ylabel('ADL (Activities of Daily Living)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-45-286885346.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Diagnosis', y='ADL', data=alzheimers_data, palette=['skyblue', 'salmon'])

# %%
# Заклучок за променливата ADL (Activities of Daily Living):
#
# Boxplot визуелизацијата прикажува јасна разлика во функционалната способност на пациентите од двете класи.
#
# Кај пациентите без Алцхајмер (Diagnosis = 0), медијаната е околу 6–7, со поширока распрсканост кон повисоки вредности (до 10),
# што укажува на високо ниво на самостојност при извршување на секојдневни активности.
#
# Кај пациентите со Алцхајмер (Diagnosis = 1), медијаната е значително пониска (околу 3),
# што укажува на зголемена функционална зависност и ограничена способност за самостојно функционирање.
#
# Овие резултати покажуваат дека ADL е силен индикатор за влијанието на Алцхајмер врз секојдневниот живот
# и претставува важна променлива во градењето класификациски модели.

# %%
# Креирање на boxplot за променливата FunctionalAssessment според дијагноза
plt.figure(figsize=(8, 6))
sns.boxplot(x='Diagnosis', y='FunctionalAssessment', data=alzheimers_data, palette=['skyblue', 'salmon'])

# Додавање на наслов и етикети на оски
plt.title('Boxplot на FunctionalAssessment според дијагноза')
plt.xlabel('Дијагноза (0 = Без Алцхајмер, 1 = Со Алцхајмер)')
plt.ylabel('Functional Assessment (Оценка на функционалност)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-47-3571281889.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Diagnosis', y='FunctionalAssessment', data=alzheimers_data, palette=['skyblue', 'salmon'])

# %%
# Заклучок за променливата FunctionalAssessment (Оценка на функционалност):
#
# Boxplot визуелизацијата прикажува значајна разлика меѓу двете класи според функционалната способност.
#
# Пациентите без Алцхајмер (Diagnosis = 0) имаат повисока медијана (околу 6.5) и поширок распон на вредности,
# што укажува на способност за самостојно извршување активности и добра општа функционалност.
#
# Пациентите со Алцхајмер (Diagnosis = 1) имаат пониска медијана (околу 3), што покажува дека тие
# имаат намалена способност за секојдневни задачи и се функционално повеќе ограничени.
#
# Оваа променлива е силен индикатор за влијанието на болеста и треба да биде вклучена во моделите за предвидување.

# %%
# Креирање на boxplot за споредба на SystolicBP (систолен крвен притисок) по дијагноза
plt.figure(figsize=(8, 6))
sns.boxplot(x='Diagnosis', y='SystolicBP', data=alzheimers_data, palette=['skyblue', 'salmon'])

# Додавање на наслов и етикети на оски
plt.title('Boxplot на SystolicBP според дијагноза')
plt.xlabel('Дијагноза (0 = Без Алцхајмер, 1 = Со Алцхајмер)')
plt.ylabel('Систолен крвен притисок (mmHg)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-49-2125807844.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Diagnosis', y='SystolicBP', data=alzheimers_data, palette=['skyblue', 'salmon'])

# %%
# Заклучок за променливата SystolicBP (Систолен крвен притисок):
#
# Boxplot визуелизацијата покажува дека дистрибуцијата на систолниот крвен притисок е слична за двете класи.
# Медијаните на пациентите со и без Алцхајмер се приближно еднакви (околу 133–135 mmHg).
#
# И двете групи имаат сличен распон и покриваат вредности од околу 90 до 180 mmHg.
# Ова укажува дека SystolicBP не е многу дискриминативна променлива помеѓу класите.
#
# Иако висок притисок може да биде ризик-фактор за когнитивни нарушувања,
# во ова податочно множество тој не прави силна разлика помеѓу класите.
# Оваа променлива најверојатно ќе има мала тежина во класификациските модели.

# %%
# Креирање на boxplot за споредба на CholesterolTotal (вкупен холестерол) по дијагноза
plt.figure(figsize=(8, 6))
sns.boxplot(x='Diagnosis', y='CholesterolTotal', data=alzheimers_data, palette=['skyblue', 'salmon'])

# Додавање на наслов и означување на оски
plt.title('Boxplot на CholesterolTotal според дијагноза')
plt.xlabel('Дијагноза (0 = Без Алцхајмер, 1 = Со Алцхајмер)')
plt.ylabel('Вкупен холестерол (mg/dL)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-51-4287528862.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Diagnosis', y='CholesterolTotal', data=alzheimers_data, palette=['skyblue', 'salmon'])

# %%
# Заклучок за променливата CholesterolTotal (Вкупен холестерол):
#
# Boxplot графиката покажува дека медијаната и дистрибуцијата на вкупниот холестерол се речиси идентични
# кај пациентите со и без Алцхајмерова болест.
#
# Медијаната е околу 220–225 mg/dL во двете класи, а распонот е од приближно 150 до 300 mg/dL.
#
# Ова укажува дека вкупниот холестерол сам по себе не е добар дискриминатор помеѓу здрави и заболени пациенти.
# Можеби ќе има придонес во моделот во комбинација со други метаболички фактори,
# но самостојно има мала предиктивна моќ за класификација на Алцхајмер.

# %%
# Креирање на корелациона матрица само за бројчани колони
corr_matrix = alzheimers_data.corr(numeric_only=True)

# Цртање на heatmap со подобрен изглед
plt.figure(figsize=(20, 20))  # Поголема слика за подобра читливост
sns.heatmap(
    corr_matrix,
    annot=True,                      # Прикажување на бројките во ќелиите
    fmt=".2f",                       # Форматирање на бројките (2 децимали)
    cmap='coolwarm',                # Боја со добар контраст (црвено-плава скала)
    linewidths=0.5,                 # Линии помеѓу ќелиите
    annot_kws={"size": 10, "color": "white"},  # Големина и боја на бројките
    cbar_kws={'label': 'Корелација'}          # Назив на боената легенда
)

# Додавање на наслов и прилагодување на оски
plt.title('Корелациска матрица на бројчани променливи', fontsize=16, pad=20)
plt.xticks(rotation=90, fontsize=12)  # Ротација на X-етикетите за читливост
plt.yticks(rotation=0, fontsize=12)   # Y-етикети без ротација
plt.tight_layout()
plt.show()

# %%
# Заклучок од анализа на корелациона матрица со таргетот 'Diagnosis'

# Од направената heatmap анализа може да се извлечат следните клучни заклучоци:

# 1. Најсилно корелирани атрибути со 'Diagnosis' се:
#    - FunctionalAssessment (-0.36), ADL (-0.33) и MMSE (-0.24) со негативна корелација,
#      што значи дека пониски оценки се поврзани со поголема веројатност за Алцхајмер.
#    - BehavioralProblems (0.22) и MemoryComplaints (0.20) со позитивна корелација,
#      што укажува на нивна поврзаност со присуство на болеста.

# 2. Сите останати променливи имаат многу слаба корелација (< |0.10|) со таргетот.
#    - Примери: Age, Gender, Smoking, Diabetes, BloodPressure, Cholesterol и други.
#    - Иако се клинички важни, статистички гледано тие не придонесуваат многу
#      за директно предвидување на дијагнозата.

# 3. Отсуството на висока меѓусебна корелација (multicollinearity) помеѓу feature-ите
#    (нема корелации > |0.7|) укажува дека можеме да ги задржиме повеќето променливи
#    без страв од преклоп или нестабилност во моделите.

# %%
# Отстранување на нерелевантни колони и целната променлива од податоците
X = alzheimers_data.drop(columns=['PatientID', 'DoctorInCharge', 'Diagnosis'])

# Зачувување на целната променлива (дијагноза) во посебна променлива y
y = alzheimers_data['Diagnosis']

# %%
# Пресметка на mutual information помеѓу секоја карактеристика и целната променлива
mi_scores = mutual_info_classif(X, y, discrete_features='auto')

# Претворање во Series и сортирање од највисока кон најниска важност
mi_series = pd.Series(mi_scores, index=X.columns).sort_values(ascending=False)

# Приказ на топ 15 најинформативни карактеристики
mi_series.head(20).plot(kind='barh')
plt.title("Mutual Information со Diagnosis")
plt.xlabel("MI Score")
plt.show()

# %%
# Заклучок од Mutual Information анализа:
#
# - Mutual Information (MI) анализата покажа кои карактеристики имаат најсилна зависност со таргетот 'Diagnosis',
#   земајќи ја предвид и линеарната и нелинеарната поврзаност.
#
# - Најинформативни променливи се:
#   FunctionalAssessment (~0.095), ADL (~0.08), MMSE (~0.065) и MemoryComplaints (~0.045).
#   Овие променливи имаат највисоки MI вредности и се најважни за предвидување на дијагнозата.
#
# - Овие карактеристики логично се поврзани со когнитивните и функционалните способности на пациентот,
#   што ги прави клучни индикатори за Алцхајмерова болест.
#
# - Променливи како Age, Diabetes, PhysicalActivity, Cholesterol и слични имаат многу ниски MI вредности (< 0.01),
#   што укажува дека тие не придонесуваат значајно за директна предикција на дијагнозата во овој датасет.
#
# - Овие резултати можат да се искористат за да се направи избор на најрелевантните feature-и за градење на модел.

# %%
# Поделба на податоците на тренинг и тест сет
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Креирање и тренирање на Random Forest класификатор
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Пресметка на важноста на карактеристиките според Random Forest
importances = pd.Series(model.feature_importances_, index=X.columns).sort_values(ascending=False)

# Приказ на топ 15 најважни карактеристики
importances.head(15).plot(kind='barh')
plt.title("Random Forest Feature Importance")
plt.xlabel("Importance")
plt.show()

# %%
# Заклучок од Random Forest Feature Importance анализа

# Random Forest моделот беше трениран со сите карактеристики за да се процени нивниот придонес кон точноста при предвидување на таргет променливата 'Diagnosis'.

# Резултатите покажуваат дека најважните променливи според моделот се:
# - FunctionalAssessment (~0.195)
# - ADL (~0.17)
# - MMSE (~0.12)
# - MemoryComplaints (~0.07)
# - BehavioralProblems (~0.045)

# Овие карактеристики се совпаѓаат со оние идентификувани како најинформативни преку Mutual Information анализа,
# што дополнително ја потврдува нивната значајност и релевантност за класификацијата.

# Од друга страна, биомедицинските атрибути како што се:
# - CholesterolLDL, SystolicBP, AlcoholConsumption, BMI
# имаат многу мала важност (<0.03), што укажува дека тие придонесуваат незначително за одлуката на моделот.

# Заклучокот од оваа анализа, заедно со резултатите од Mutual Information, сугерира дека финалниот модел
# треба да вклучи само најважните 5-8 карактеристики, со цел да се подобри перформансата и да се намали комплексноста,
# елиминирајќи ги оние карактеристики кои носат мала или никаква дополнителна информација.

# %%
# Feature Selection со Recursive Feature Elimination (RFE)
# Овој чекор автоматски избира 10 најдобри feature-и базирано на перформансите на Random Forest моделот

# Креирање на селектор кој задржува 10 најдобри променливи
selector = RFE(RandomForestClassifier(), n_features_to_select=10)
selector.fit(X_train, y_train)

# Избор на најдобрите feature-и според селекторот
X_selected = X_train.loc[:, selector.support_]

# Приказ на избраните имиња на променливите
selected_features = X_selected.columns.tolist()
print("Избрани feature-и од RFE:", selected_features)
# Out:
# Избрани feature-и од RFE: ['PhysicalActivity', 'DietQuality', 'SleepQuality', 'CholesterolHDL', 'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment', 'MemoryComplaints', 'BehavioralProblems', 'ADL']

# %%
# Преземање на топ 15 карактеристики според Mutual Information
mi_top = mi_series.sort_values(ascending=False).head(15).index.tolist()
print(mi_top)

# Преземање на топ 15 карактеристики според Random Forest важноста
rf_top = importances.sort_values(ascending=False).head(15).index.tolist()
print(rf_top)

# Преземање на карактеристики избрани со RFE (Recursive Feature Elimination)
rfe_top = X_selected.columns.tolist()
print(rfe_top)
# Out:
# ['FunctionalAssessment', 'ADL', 'MMSE', 'MemoryComplaints', 'AlcoholConsumption', 'BehavioralProblems', 'CholesterolHDL', 'SleepQuality', 'PersonalityChanges', 'PhysicalActivity', 'Depression', 'HeadInjury', 'Gender', 'CardiovascularDisease', 'CholesterolTotal']
# ['FunctionalAssessment', 'ADL', 'MMSE', 'MemoryComplaints', 'BehavioralProblems', 'CholesterolHDL', 'PhysicalActivity', 'DietQuality', 'CholesterolTriglycerides', 'CholesterolTotal', 'BMI', 'SleepQuality', 'AlcoholConsumption', 'SystolicBP', 'CholesterolLDL']
# ['PhysicalActivity', 'DietQuality', 'SleepQuality', 'CholesterolHDL', 'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment', 'MemoryComplaints', 'BehavioralProblems', 'ADL']

# %%
# Комбинирање на трите листи со најважни карактеристики (од MI, RF и RFE)
# set() отстранува дупликати, list() ја претвора назад во листа
final_features = list(set(mi_top + rf_top + rfe_top))

# Приказ на финалната листа со селектирани фичи
final_features
# Out:
# ['Depression',
#  'SleepQuality',
#  'Gender',
#  'PhysicalActivity',
#  'FunctionalAssessment',
#  'CholesterolLDL',
#  'CholesterolTotal',
#  'MemoryComplaints',
#  'BehavioralProblems',
#  'MMSE',
#  'CholesterolTriglycerides',
#  'HeadInjury',
#  'DietQuality',
#  'SystolicBP',
#  'PersonalityChanges',
#  'ADL',
#  'AlcoholConsumption',
#  'CardiovascularDisease',
#  'CholesterolHDL',
#  'BMI']

# %%
# Креирање на финален податочен сет со селектираните карактеристики
X_final = X[final_features]

# Поделба на финалниот сет на тренинг и тест податочно множество
X_train_f, X_test_f, y_train_f, y_test_f = train_test_split(
    X_final, y, test_size=0.2, random_state=42, stratify=y)

# %%
# Дефинирање на хиперпараметри за GridSearchCV
param_grid = {
    'solver': ['lsqr', 'eigen'],           # методи за оптимизација
    'shrinkage': [None, 'auto', 0.1, 0.5, 0.9]     # важи само за 'lsqr' и 'eigen'
}

# %%
# Креирање на GridSearch со 5-кратна крос-валидација и оценување според accuracy
lda = LinearDiscriminantAnalysis()
grid_search = GridSearchCV(lda, param_grid, cv=5, scoring='recall',verbose=1)
grid_search.fit(X_train_f, y_train_f)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# GridSearchCV(cv=5, estimator=LinearDiscriminantAnalysis(),
#              param_grid={'shrinkage': [None, 'auto', 0.1, 0.5, 0.9],
#                          'solver': ['lsqr', 'eigen']},
#              scoring='recall', verbose=1)

# %%
# Приказ на најдобрите хиперпараметри
print("Најдобри параметри:", grid_search.best_params_)
# Out:
# Најдобри параметри: {'shrinkage': None, 'solver': 'lsqr'}

# %%
# Заклучок од LDA GridSearch анализа
#
# Најдобрите хиперпараметри пронајдени со GridSearch се:
# - solver = 'lsqr'
# - shrinkage = None
#
# ➤ Ова значи дека податоците имаат доволно стабилна коваријансна матрица
#    и не е потребна дополнителна регуларизација (shrinkage),
#    но сепак е потребен стабилен метод за решавање како 'lsqr'.
#
# GridSearch автоматски ја избра оптималната конфигурација,
# што ја зголемува довербата во моделот и минимизира ризик од рачна грешка.
#
# Следниот чекор е да ја процениме перформансата на моделот
# преку classification report, confusion matrix и ROC-AUC.

# %%
# Предикција со моделот што дал најдобри резултати
best_lda = grid_search.best_estimator_
y_pred = best_lda.predict(X_test_f)

# %%
# Креирање на конфузиона матрица врз основа на вистинските и предвидените вредности
cm = confusion_matrix(y_test_f, y_pred)

# Приказ на конфузионата матрица како график со етикети
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Disease', 'Disease'])
disp.plot(cmap='Blues')  # Боја на матрицата
plt.title("🧠 Confusion Matrix за LDA")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129504 (\N{BRAIN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Заклучок од Confusion Matrix за LDA:

# 📊 Матрицата го покажува следното:
# - True Positives (TP): 112 пациенти со болест точно предвидени како болни.
# - True Negatives (TN): 238 здрави пациенти точно предвидени како здрави.
# - False Negatives (FN): 40 пациенти со болест кои моделот погрешно ги предвидел како здрави.
# - False Positives (FP): 40 здрави пациенти кои моделот погрешно ги предвидел како болни.

# 🔎 Анализа:
# - FN (False Negatives) се особено критични во медицински контекст, бидејќи значат промашени дијагнози – тука се 40 случаи,
#   што укажува дека моделот може дополнително да се подобри за да ја зголеми чувствителноста (recall).
#
# - FP (False Positives) се исто така 40, што значи дека неколку здрави пациенти би можеле непотребно да добијат дополнителни прегледи,
#   но ова е подобро сценарио отколку да се пропуштат пациенти со болест.
#
# ✅ Генерално, моделот покажува добар баланс помеѓу чувствителност (вистинско откривање на болеста) и специфичност (правилно препознавање на здравите),
#   со стабилни перформанси и потенцијал за уште подобри резултати преку понатамошно прилагодување на моделот или користење на други техники за справување со нерамнотежа.

# %%
# Приказ на classification метрики (precision, recall, f1-score)
print("📊 Classification Report:")
print(classification_report(y_test_f, y_pred))
# Out:
# 📊 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86       278
#            1       0.74      0.73      0.74       152
#
#     accuracy                           0.81       430
#    macro avg       0.80      0.79      0.80       430
# weighted avg       0.81      0.81      0.81       430

# %%
# Заклучок од Classification Report за LDA моделот:
#
# ✅ Моделот постигнува вкупна точност (accuracy) од 81%, што е многу солидно за медицинска задача.
#
# ➤ За класа 0 (без болест):
# - Precision: 0.86 → моделот е многу точен во идентификација на здравите пациенти.
# - Recall: 0.86 → моделот успешно ги препознава најголем дел од здравите.
#
# ➤ За класа 1 (со болест):
# - Precision: 0.74 → околу 74% од пациентите предвидени како болни навистина се болни.
# - Recall: 0.74 → моделот открива 74% од пациентите со болест, но 26% од болните остануваат непрепознаени (False Negatives).
#
# ➤ F1-score за класа 1 е 0.74 → ова значи урамнотежена перформанса помеѓу прецизност и чувствителност,
# но има простор за подобрување со фокус на зголемување на recall за оваа класа.
#
# ➤ Просечните метрики (macro avg и weighted avg) од околу 0.80-0.81 ја потврдуваат стабилноста на моделот
# низ класите и покажуваат дека LDA има добар потенцијал во предикција на Алцхајмер.

# %%
# Пресметка на ROC-AUC за дополнителна евалуација на моделот
y_prob = best_lda.predict_proba(X_test_f)[:, 1]
print("🎯 ROC-AUC:", roc_auc_score(y_test_f, y_prob))
# Out:
# 🎯 ROC-AUC: 0.882596554335479

# %%
# Заклучок од ROC-AUC анализа:
#
# ✅ Пресметаниот ROC-AUC за LDA моделот е 0.88, што значи дека моделот многу добро ги
# разликува пациентите со и без Алцхајмер.
#
# ➤ Што значи AUC вредноста?
# - AUC = 0.88 → Моделот има 88% веројатност да рангира случаен пациент со болест
#   повисоко од случаен пациент без болест.
#
# ➤ Зошто ова е важно?
# - Висока ROC-AUC укажува дека моделот одржува добар баланс меѓу чувствителност и специфичност
#   при различни праг вредности (thresholds), што е особено важно во медицина каде се менува прагот
#   за да се намалат пропуштените случаи (FN) или лажно алармирање (FP).
#
# ➤ Практична интерпретација:
# - Овој резултат потврдува дека LDA моделот е стабилен и доверлив за дијагноза,
#   но за да се подобри recall, може да се прилагоди decision threshold или да се испробаат
#   напредни техники како ensemble или balancing на класите.

# %%
# Креирање на LDA модел за визуелизација со solver='svd'
lda_vis = LinearDiscriminantAnalysis(solver='svd')

# Трансформација на тест податочното множество во 1D LDA простор
X_lda_vis = lda_vis.fit(X_train_f, y_train_f).transform(X_test_f)

# Приказ на хистограм со проектираните вредности за двете класи
plt.figure(figsize=(8, 4))
plt.hist(X_lda_vis[y_test_f == 0], bins=20, alpha=0.7, label='Class 0', color='blue')
plt.hist(X_lda_vis[y_test_f == 1], bins=20, alpha=0.7, label='Class 1', color='red')
plt.title("🔍 LDA проекција на тест сетот (со solver='svd')")
plt.xlabel("LDA компонента")
plt.ylabel("Број на примери")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-75-1468861637.py:15: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Заклучок од LDA визуелизацијата:
#
# 📌 Проекцијата на податоците во 1D LDA простор јасно прикажува дека двете класи (Class 0 - без болест и Class 1 - со болест)
# се добро раздвоени по првата LDA компонента.
#
# ✅ Класа 0 е концентрирана на левата страна од графикот, додека класа 1 е поместена кон десно,
# што потврдува дека LDA моделот наоѓа линеарна комбинација од карактеристики
# која овозможува стабилна дискриминација помеѓу пациентите со и без дијагноза.
#
# ⚠️ Забележливо е мало преклопување помеѓу класите во централниот дел на графикот,
# што објаснува појавата на False Positives и False Negatives во Confusion Matrix и помал recall за класа 1.
#
# 🧐 Визуелизацијата е во согласност со добрите резултати од accuracy и ROC-AUC,
# и дополнително ја потврдува способноста на моделот да прави разлика помеѓу класите.

# %%
# Обука на LDA со class_weight (чувствителност на нерамнотежа)

# Пресметка на тежини базирано на фреквенција
classes = np.unique(y_train_f)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train_f)

# Креирање LDA модел со поставени prior-и според тежините
lda_weighted = LinearDiscriminantAnalysis(solver='lsqr', shrinkage=None, priors=weights / weights.sum())
lda_weighted.fit(X_train_f, y_train_f)
# Out:
# LinearDiscriminantAnalysis(priors=array([0.35369401, 0.64630599]),
#                            solver='lsqr')

# %%
# Предикција со моделот кој користи тежини (cost-sensitive LDA)
y_pred_weighted = lda_weighted.predict(X_test_f)

# %%
# Конфузиона матрица за cost-sensitive LDA
cm_weighted = confusion_matrix(y_test_f, y_pred_weighted)
disp_weighted = ConfusionMatrixDisplay(confusion_matrix=cm_weighted, display_labels=['No Disease', 'Disease'])
disp_weighted.plot(cmap='Purples')  # Нов стил за разликување
plt.title("📘 Confusion Matrix - Cost-sensitive LDA")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128216 (\N{BLUE BOOK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Заклучок од Confusion Matrix - Cost-sensitive LDA:
#
# ✅ Моделот со прилагодени тежини постигна значително подобрување на чувствителноста кон класа 1 (болни пациенти):
#   - True Positives (болни правилно предвидени): 137 од 152 (recall ≈ 0.90),
#   - False Negatives: само 15 случаи на пропуштени болни пациенти,
#   што претставува драстично намалување на FN во споредба со стандардниот LDA модел.
#
# ⚠️ Истовремено, се зголемија False Positives (здрави предвидени како болни) на 86,
# што доведе до намалена специфичност (точност за здрави пациенти).
#
# 📊 Иако точноста за класа 0 (No Disease) се намали (TP=192), ова сценарио е прифатливо во медицински контекст,
# каде што поважно е да не се пропушти болен пациент (повисок recall за класа 1).
#
# 🔎 Генерално, cost-sensitive LDA обезбедува подобар баланс за задачи каде повисок recall за позитивната класа
# е критичен (на пр. рано откривање на болест), и ја прави класификацијата посоодветна за медицински апликации
# каде лажна негативна дијагноза може да има сериозни последици.

# %%
print("📋 Classification Report - Cost-sensitive LDA:")
print(classification_report(y_test_f, y_pred_weighted))
# Out:
# 📋 Classification Report - Cost-sensitive LDA:
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.79       278
#            1       0.61      0.90      0.73       152
#
#     accuracy                           0.76       430
#    macro avg       0.77      0.79      0.76       430
# weighted avg       0.81      0.76      0.77       430

# %%
# Заклучок од Classification Report - Cost-sensitive LDA:
#
# ✅ Со примената на cost-sensitive пристап преку прилагодени prior-и, моделот постигна значајно подобрување на чувствителноста (recall) за критичната класа 1 (пациенти со болест):
#   - Recall за класа 1 достигна 0.90, што значи дека моделот успешно открива 90% од пациентите со дијагноза,
#     што е од клучно значење во медицински контекст каде пропуштањето на болен пациент може да има сериозни последици.
#
# ⚠️ Компромисот за ова подобрување е намалување на precision за класа 1 на 0.61,
# што значи дека моделот почесто класифицира здрави пациенти како болни (повеќе False Positives).
# Ова е типичен trade-off кај модели кои се оптимизирани за повисок recall.
#
# 🩺 Кај класа 0 (здрави пациенти), моделот задржа висока precision од 0.93, но recall се намали на 0.69,
# што укажува дека дел од здравите беа неправилно предвидени како болни.
#
# 📊 F1-score за класа 1 (0.73) демонстрира урамнотежена перформанса меѓу точност и чувствителност,
# додека вкупната точност на моделот изнесува 77% - нешто пониска од стандардниот модел, но со значително подобрен recall за класа 1.
#
# 🔎 Овој резултат потврдува дека cost-sensitive LDA е посоодветен избор за задачи каде критичен приоритет е да се минимизираат False Negatives,
# односно да се откријат што е можно повеќе пациенти со болест, дури и по цена на повеќе False Positives.
#
# 👉 Во клиничка примена, оваа стратегија може да придонесе кон подобро рано детектирање на болеста и да ја зголеми шансата за навремено лекување.

# %%
# Креирање на модел за Квадратна дискриминантна анализа (QDA)
qda = QuadraticDiscriminantAnalysis()

# Тренирање на QDA моделот со финалниот тренинг сет
qda.fit(X_train_f, y_train_f)
# Out:
# QuadraticDiscriminantAnalysis()

# %%
# Предикција на класите од тест сетот користејќи го тренираниот QDA модел
y_pred_qda = qda.predict(X_test_f)

# %%
# Конфузиона матрица за QDA моделот
cm_qda = confusion_matrix(y_test_f, y_pred_qda)

# Приказ на конфузионата матрица со етикети
disp_qda = ConfusionMatrixDisplay(confusion_matrix=cm_qda, display_labels=['No Disease', 'Disease'])
disp_qda.plot(cmap='Greens')  # Боја на матрицата
plt.title("Confusion Matrix - QDA")
plt.show()

# %%
# Заклучок од Confusion Matrix за QDA моделот:
#
# 🟢 QDA моделот покажува солидна способност за разликување на класите, со следниве резултати:
#   - True Negatives (TN): 230 здрави пациенти се точно идентификувани како здрави.
#   - True Positives (TP): 117 пациенти со болест се правилно препознаени како болни.
#   - False Negatives (FN): 35 болни пациенти се класифицирани како здрави, што укажува на ризик за пропуштање на дијагноза.
#   - False Positives (FP): 48 здрави пациенти се предвидени како болни, што може да доведе до непотребни дополнителни испитувања.
#
# 📊 Анализата покажува дека QDA има подобра рамнотежа помеѓу чувствителност и специфичност во споредба со класичен LDA,
# но не ја достигнува чувствителноста на cost-sensitive LDA моделот. И покрај тоа, QDA намалува број на False Negatives
# во однос на стандардниот LDA, што е критично за медицински апликации каде пропуштањето на болни пациенти треба да се минимизира.
#
# ✅ Генерално, QDA демонстрира добра дискриминација, но со умерен број на лажно позитивни случаи.
# Овој компромис го прави корисен во клинички сценарија каде што и чувствителноста и специфичноста се важни.

# %%
# Метрики за QDA
print("📋 Classification Report - QDA:")
print(classification_report(y_test_f, y_pred_qda))
# Out:
# 📋 Classification Report - QDA:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       278
#            1       0.71      0.77      0.74       152
#
#     accuracy                           0.81       430
#    macro avg       0.79      0.80      0.79       430
# weighted avg       0.81      0.81      0.81       430

# %%
# Заклучок од Classification Report - QDA:
#
# 📊 QDA моделот постигнува вкупна точност (accuracy) од 81%, што е споредливо со стандардниот LDA,
# но прикажува подобра чувствителност (recall) за класа 1 (болни пациенти) од 77%,
# што значи дека QDA успешно идентификува над три четвртини од пациентите со дијагноза.
#
# Precision за класа 1 е 71%, што укажува дека 29% од пациентите предвидени како болни всушност се здрави
# (false positives), но ова е прифатлив компромис во медицински контекст каде што е поважно да не се пропуштат болни.
#
# F1-score за класа 1 е 0.74, што демонстрира добра рамнотежа помеѓу чувствителност и точност за детекција на болеста.
# Во однос на здравата класа (класа 0), моделот задржува висока прецизност (87%) и чувствителност (83%),
# што обезбедува стабилна класификација и за таа група.
#
# ✅ Генерално, QDA моделот покажува добра способност за справување со посложени структури на податоци
# благодарение на дозволата за различни коваријансни матрици по класа, што овозможува пофлексибилно раздвојување на класите.
#
# QDA претставува одлична опција кога се бара балансиран однос меѓу ниски лажни аларми и доволна чувствителност,
# без агресивни компромиси како кај cost-sensitive пристапите.

# %%
# Пресметка на веројатности за класа 1
y_prob_qda = qda.predict_proba(X_test_f)[:, 1]

# Пресметка на ROC-AUC
roc_auc_qda = roc_auc_score(y_test_f, y_prob_qda)
print("🎯 ROC-AUC за QDA:", roc_auc_qda)
# Out:
# 🎯 ROC-AUC за QDA: 0.8688706929193487

# %%
# 📊 Заклучок од споредба помеѓу LDA (cost-sensitive) и QDA:
#
# ▶️ LDA (со прилагодени тежини за класите):
# - 🩺 Recall за класа 1 (болни пациенти): 90% ➔ Одличен за откривање болни случаи.
# - 🎯 Precision: 61% ➔ Значителен број False Positives (лажни аларми).
# - ✅ Accuracy: 77% ➔ Намалена точност поради агресивно „фаќање“ на болни.
# - 📈 ROC-AUC: 0.88 ➔ Одлична дискриминантна моќ.
#
# ▶️ QDA (стандардна верзија):
# - 🩺 Recall за класа 1: 77% ➔ Солидна чувствителност, но пониска од cost-sensitive LDA.
# - 🎯 Precision: 71% ➔ Подобар баланс со помалку лажни аларми.
# - ✅ Accuracy: 81% ➔ Повисока точност и стабилност.
# - 📈 ROC-AUC: 0.87 ➔ Речиси идентичен со LDA.
#
# 🧠 Што значат овие разлики?
# - LDA е најсоодветен ако најголем приоритет е **максимално откривање на болни пациенти**
#   и е прифатливо да има повеќе лажни аларми (FP). Овој пристап е корисен во ситуации каде
#   пропуштањето болен пациент би имало сериозни последици.
#
# - QDA обезбедува подобар **баланс меѓу чувствителност и прецизност**,
#   со повисока вкупна точност и помалку лажни аларми, што го прави поприлагоден за ситуации
#   каде што се сака да се избегне непотребна паника или интервенции.
#
# 🔎 Иако и двата модели имаат сличен ROC-AUC (~0.87–0.88), нивното однесување е различно:
# - LDA ➔ повеќе чувствителен, но со повеќе False Positives.
# - QDA ➔ подобро избалансиран и поточен во предвидувањата.
#
# 🏁 Финален совет: изборот треба да зависи од клиничкиот приоритет:
# ➔ Ако најважно е да не се пропушти дијагноза ➔ користи LDA.
# ➔ Ако е важно да се задржи точност и да се намалат лажните аларми ➔ користи QDA.

# %%
# Креирање на Naïve Bayes класификатор со Гаусова распределба
nb = GaussianNB()

# Тренирање на Naïve Bayes моделот со финалниот тренинг сет
nb.fit(X_train_f, y_train_f)
# Out:
# GaussianNB()

# %%
# Предикција на класите од тест сетот користејќи го Naïve Bayes моделот
y_pred_nb = nb.predict(X_test_f)

# %%
# Креирање на конфузиона матрица за Naïve Bayes моделот
cm_nb = confusion_matrix(y_test_f, y_pred_nb)

# Приказ на конфузионата матрица со етикети за двете класи
disp_nb = ConfusionMatrixDisplay(confusion_matrix=cm_nb, display_labels=['No Disease', 'Disease'])
disp_nb.plot(cmap='Oranges')  # Боја на матрицата
plt.title("Confusion Matrix - Naïve Bayes")
plt.show()

# %%
# Заклучок од Confusion Matrix за Naïve Bayes моделот:
#
# 🟠 Naïve Bayes моделот покажува солидна способност за класификација, со следниве резултати:
#   - True Negatives (TN): 225 здрави пациенти се точно идентификувани како здрави.
#   - True Positives (TP): 110 пациенти со болест се правилно препознаени како болни.
#   - False Negatives (FN): 42 болни пациенти се класифицирани како здрави, што носи ризик за пропуштање на дијагноза.
#   - False Positives (FP): 53 здрави пациенти се предвидени како болни, што може да предизвика непотребни дополнителни испитувања.
#
# 📊 Анализата покажува дека Naïve Bayes има добра вкупна точност и стабилна перформанса,
# но бројот на False Negatives е поголем во споредба со QDA и cost-sensitive LDA,
# што го прави помалку погоден за апликации каде е критично да не се пропуштат болни пациенти.
#
# ✅ Најдобро е да се користи Naïve Bayes кога едноставноста и брзината се приоритет,
# но за чувствителни медицински случаи, потребни се дополнителни техники за подобрување на recall.

# %%
# 📊 Приказ на метрики за Naïve Bayes моделот:
# вклучува precision, recall, f1-score и support по класа
print("📊 Classification Report за Naïve Bayes:")
print(classification_report(y_test_f, y_pred_nb))
# Out:
# 📊 Classification Report за Naïve Bayes:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82       278
#            1       0.68      0.69      0.68       152
#
#     accuracy                           0.77       430
#    macro avg       0.75      0.76      0.75       430
# weighted avg       0.78      0.77      0.77       430

# %%
# Заклучок од Classification Report за Naïve Bayes моделот:
#
# 🟠 Моделот постигна вкупна точност (accuracy) од 78%, што укажува на стабилна перформанса при класификација на двете класи.
#
# 🔹 Класа 0 (здрави пациенти):
#   - Precision: 84% (голем дел од предвидените здрави навистина се здрави)
#   - Recall: 81% (81% од сите здрави пациенти се точно препознаени)
#   - F1-score: 0.82, што покажува урамнотежена перформанса за оваа класа.
#
# 🔸 Класа 1 (болни пациенти):
#   - Precision: 68% (поголем број на False Positives во однос на другите модели)
#   - Recall: 71% (моделот препознава 71% од болните, но сè уште пропушта значаен дел)
#   - F1-score: 0.69, што укажува на послаба рамнотежа меѓу точност и чувствителност за оваа критична класа.
#
# 📊 Просечните метрики (macro avg и weighted avg) се околу 0.76–0.78, што е во согласност со вкупната точност
# и покажува дека Naïve Bayes има релативно добра стабилност меѓу класите.
#
# ✅ Генерално, Naïve Bayes моделот е едноставен и брз за тренирање, но во овој здравствен контекст
# покажува ограничувања во recall за класа 1, што може да резултира со пропуштени болни пациенти.
# За критични медицински апликации би било препорачливо да се користи пософистициран модел или техники за подобрување на чувствителноста.

# %%
# Пресметка на веројатностите за класата 1 (пациенти со болест)
y_prob_nb = nb.predict_proba(X_test_f)[:, 1]

# Пресметка на ROC-AUC метриката за Naïve Bayes моделот
roc_auc_nb = roc_auc_score(y_test_f, y_prob_nb)
print("🎯 ROC-AUC за Naïve Bayes:", roc_auc_nb)
# Out:
# 🎯 ROC-AUC за Naïve Bayes: 0.8504827716773949

# %%
# Заклучок за ROC-AUC и перформансите на Naïve Bayes моделот:
#
# 🎯 Naïve Bayes постигна ROC-AUC од 0.856, што укажува на добра способност за разликување
# помеѓу пациенти со и без болест. Тоа значи дека постои 85.6% шанса моделот да додели
# повисока веројатност на случаен болен пациент отколку на случаен здрав пациент.
#
# 📊 Иако ROC-AUC е солиден, деталните метрики покажуваат ограничувања кај класа 1:
#   - Precision за класа 1 (болни пациенти): 68% → што значи дека 32% од пациентите
#     кои се предвидени како болни се всушност здрави (False Positives).
#   - Recall за класа 1: 71% → моделот успешно препознава околу 71% од болните пациенти,
#     но пропушта 29% од нив (False Negatives), што е значаен ризик во медицински апликации.
#
# 🟠 Моделот се одликува со подобра перформанса кај класа 0 (здрави пациенти), но тоа води до пристрасност
# и потенцијално пропуштање на болни пациенти.
#
# ✅ Генерално, Naïve Bayes е едноставен и брз модел со добра ROC-AUC дискриминантна моќ,
# но перформансите за критичната класа 1 не се доволни за доверлива примена во здравствен контекст.
# Препорачливо е користење на техники како cost-sensitive учење или комбинирање со други модели
# за подобрување на чувствителноста кон болните пациенти.

# %%
# Креирање на Naïve Bayes модел со поставени приоритети (prior веројатности)
# Класа 1 (болни) добива повисока важност → 70% приоритет
nb_weighted = GaussianNB(priors=[0.3, 0.7])

# Тренирање на моделот со приоритети врз финалниот тренинг сет
nb_weighted.fit(X_train_f, y_train_f)
# Out:
# GaussianNB(priors=[0.3, 0.7])

# %%
# Предикција на класите од тест сетот со Naïve Bayes модел со приоритет за класа 1
y_pred_weighted = nb_weighted.predict(X_test_f)

# %%
# Предикција на класите со Naïve Bayes модел кој дава приоритет на болните пациенти
y_pred_weighted = nb_weighted.predict(X_test_f)

# Креирање и приказ на конфузиона матрица за cost-sensitive Naïve Bayes моделот
cm_weighted_nb = confusion_matrix(y_test_f, y_pred_weighted)
disp_weighted_nb = ConfusionMatrixDisplay(confusion_matrix=cm_weighted_nb, display_labels=['No Disease', 'Disease'])
disp_weighted_nb.plot(cmap='Purples')  # Виолетова боја за разликување
plt.title("🧪 Confusion Matrix - Cost-sensitive Naïve Bayes")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129514 (\N{TEST TUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Заклучок од Confusion Matrix за Cost-sensitive Naïve Bayes моделот:
#
# 🟣 Со примената на приоритет (priors) кои даваат поголема тежина на класа 1 (болни пациенти),
# моделот постигна следниве резултати:
#   - True Positives (TP): 136 пациенти со болест се точно идентификувани како болни.
#   - True Negatives (TN): 177 здрави пациенти се правилно класифицирани како здрави.
#   - False Positives (FP): 101 здрав пациент е лажно класифициран како болен,
#     што значи зголемување на лажно позитивните случаи.
#   - False Negatives (FN): 16 болни пациенти се предвидени како здрави, што е значително подобрување
#     во однос на стандардниот Naïve Bayes модел (кој имаше 42 FN).
#
# 📊 Анализата покажува дека cost-sensitive Naïve Bayes го намалува бројот на пропуштени болни (FN)
# од 42 → 16, што значи дека чувствителноста кон класа 1 се подобрува значајно.
# Но, ова се постигнува со компромис: драстично се зголемува бројот на False Positives (од 53 → 101),
# што може да доведе до непотребни дијагностички процедури кај здрави пациенти.
#
# ✅ Генерално, cost-sensitive Naïve Bayes ја подобрува способноста за откривање на болни пациенти,
# што го прави поадекватен во ситуации каде приоритет е минимизирање на пропуштени дијагнози,
# иако тоа се постигнува со цената на поголем број лажно алармирани здрави пациенти.

# %%
# 📋 Приказ на класификациски метрики за моделот со приоритет на класа 1 (болни)
print("📋 Classification Report - Cost-sensitive Naïve Bayes:")
print(classification_report(y_test_f, y_pred_weighted))
# Out:
# 📋 Classification Report - Cost-sensitive Naïve Bayes:
#               precision    recall  f1-score   support
#
#            0       0.92      0.64      0.75       278
#            1       0.58      0.90      0.70       152
#
#     accuracy                           0.73       430
#    macro avg       0.75      0.77      0.73       430
# weighted avg       0.80      0.73      0.74       430

# %%
# Заклучок од Classification Report за Cost-sensitive Naïve Bayes моделот:
#
# 📊 Приказот на метриките покажува значајни промени во перформансата на моделот:
#
# ▶️ Класа 1 (болни пациенти):
#   - Recall се подобри драматично на 89% (од 71% кај стандардниот NB), што значи дека моделот
#     успешно препознава поголем дел од болните пациенти.
#   - Precision опадна на 57%, што укажува дека над 40% од предвидените болни пациенти се всушност здрави
#     (значителен пораст на False Positives).
#   - F1-score за класа 1 е 0.70, што претставува подобра чувствителност со компромис во точноста.
#
# ▶️ Класа 0 (здрави пациенти):
#   - Precision останува висок на 92%, но recall падна на 64%, што значи дека моделот почесто
#     греши и здравите ги предвидува како болни (лажни аларми).
#
# ▶️ Вкупни метрики:
#   - Точноста (accuracy) падна на 73% поради порастот на лажно позитивни случаи.
#   - Macro average F1-score е 0.73, што покажува умерен баланс меѓу двете класи.
#
# ✅ Генерално, cost-sensitive Naïve Bayes успева значително да ја зголеми чувствителноста кон болните пациенти,
# што е критично во клинички контекст. Сепак, компромисот е намалена специфичност и повисок број на лажно позитивни случаи,
# што може да доведе до непотребни интервенции кај здравите пациенти.

# %%
# Пресметка на веројатноста дека секој пример припаѓа на класа 1 (болни)
y_prob_weighted = nb_weighted.predict_proba(X_test_f)[:, 1]

# Пресметка на ROC-AUC метриката за моделот со приоритет на класа 1
roc_auc_weighted = roc_auc_score(y_test_f, y_prob_weighted)
print("🎯 ROC-AUC за Cost-sensitive Naïve Bayes:", roc_auc_weighted)
# Out:
# 🎯 ROC-AUC за Cost-sensitive Naïve Bayes: 0.8504827716773949

# %%
# Заклучок за Cost-sensitive Naïve Bayes моделот:
#
# 📊 Моделот беше трениран со приоритети поставени на класа 1 (болни пациенти) со 70% важност,
# што резултираше со значајно зголемена чувствителност кон болната класа.
#
# ▶️ Од classification report:
#   - Класа 1 (болни пациенти):
#       - Recall достигна 89%, што значи дека моделот успешно препознава 89% од болните пациенти,
#         што е критично во медицински апликации.
#       - Precision е 57%, што укажува на зголемен број лажно позитивни случаи (FP).
#   - Класа 0 (здрава):
#       - Precision е висока (92%), но recall падна на 64%, што значи повеќе здрави пациенти
#         се погрешно класифицирани како болни.
#   - Вкупна точност (accuracy) се намали на 73% поради порастот на False Positives.
#   - Macro average F1-score е 0.73, што укажува на умерен баланс помеѓу чувствителност и прецизност.
#
# 🎯 ROC-AUC = 0.85 → покажува стабилна дискриминантна моќ на моделот,
# слична на другите модели како QDA и LDA, но со фокус на зголемување на recall за болните.
#
# ✅ Генерално, Cost-sensitive Naïve Bayes е многу корисен кога примарната цел е
# минимизирање на пропуштените дијагнози кај болни пациенти (висок recall),
# иако тоа доаѓа со компромис во точноста и поголем број лажно позитивни случаи.

# %%
# Креирање на објект за стандардизација (скалирање на податоците)
scaler = StandardScaler()

# Фитување (учење на параметрите) врз тренинг сетот и трансформирање на истиот
X_train_scaled = scaler.fit_transform(X_train_f)

# Применување на истите параметри за трансформација на тест сетот
X_test_scaled = scaler.transform(X_test_f)

# %%
# Дефинирање на мрежа на хиперпараметри за GridSearch кај логистичка регресија
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],        # Јачина на регуларизација (помало C = посилна регуларизација)
    'penalty': ['l2'],                   # Тип на регуларизација (L2 е поддржан од 'lbfgs' и 'saga')
    'solver': ['lbfgs', 'saga'],         # Избор на оптимизациски алгоритам
    'max_iter': [100, 500]               # Максимален број на итерации за конвергенција
}

# %%
# Инстанцирање на Logistic Regression модел (без тренинг)
log_reg = LogisticRegression()

# Креирање на GridSearchCV за пронаоѓање на најдобри хиперпараметри
grid_search_lr = GridSearchCV(
    estimator=log_reg,
    param_grid=param_grid,       # Мрежата со вредности за тестирање
    cv=5,                        # 5-кратна крос-валидација
    scoring='recall',            # Фокус на recall за да фатиме што повеќе болни пациенти
    n_jobs=-1,                   # Паралелна обработка со сите достапни јадра
    verbose=1                    # Приказ на текот на GridSearch
)

# Тренирање на GridSearch моделот со тренинг податоците
grid_search_lr.fit(X_train_scaled, y_train_f)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100], 'max_iter': [100, 500],
#                          'penalty': ['l2'], 'solver': ['lbfgs', 'saga']},
#              scoring='recall', verbose=1)

# %%
# Приказ на најдобрите параметри
print("Најдобри параметри:", grid_search_lr.best_params_)
# Out:
# Најдобри параметри: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}

# %%
# Земање на најдобриот Logistic Regression модел според GridSearch
best_lr = grid_search_lr.best_estimator_

# Предикција на класите од тест сетот со најдобриот модел
y_pred_lr = best_lr.predict(X_test_f)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
# Креирање на конфузиона матрица за Logistic Regression моделот
cm_lr = confusion_matrix(y_test_f, y_pred_lr)

# Визуелизација на конфузионата матрица со етикети
disp_lr = ConfusionMatrixDisplay(confusion_matrix=cm_lr, display_labels=['No Disease', 'Disease'])
disp_lr.plot(cmap='Blues')  # Сина палета за визуелна разлика
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

# %%
# 📊 Заклучок од Confusion Matrix за Logistic Regression моделот:
#
# 🔵 Logistic Regression моделот покажува следни резултати на тест сетот:
#   - True Negatives (TN): 239 здрави пациенти точно класифицирани како здрави.
#   - True Positives (TP): 57 пациенти со болест точно идентификувани како болни.
#   - False Negatives (FN): 95 болни пациенти кои моделот ги предвидел како здрави – висок ризик за пропуштање на дијагноза.
#   - False Positives (FP): 39 здрави пациенти предвидени како болни – умерен број на лажно позитивни.
#
# 📉 Овој модел има значителен број на False Negatives (95), што значи дека Logistic Regression не успева да фати
# добар дел од болните пациенти, што е критично во медицинска апликација.
#
# 📌 И покрај доброто идентификување на здрави пациенти (висок TN), нискиот број на TP и високиот број на FN
# укажуваат дека Logistic Regression во оваа конфигурација не е доволно чувствителен за класа 1.
#
# ✅ Заклучок: Logistic Regression не обезбедува доволна чувствителност за предвидување на пациенти со болест,
# што ја прави помалку соодветна за ситуации каде приоритет е откривање на сите болни случаи.
# Неопходно е дополнително прилагодување или избор на друг модел со подобар recall за болните.

# %%
# Приказ на прецизност, чувствителност и F1 резултати
print("📋 Classification Report за Logistic Regression:")
print(classification_report(y_test_f, y_pred_lr))
# Out:
# 📋 Classification Report за Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.70      0.89      0.78       278
#            1       0.60      0.30      0.40       152
#
#     accuracy                           0.68       430
#    macro avg       0.65      0.60      0.59       430
# weighted avg       0.66      0.68      0.65       430

# %%
# 📋 Заклучок од Classification Report за Logistic Regression:
#
# 📊 Според метриките од извештајот:
# - Класа 0 (No Disease): precision = 0.72, recall = 0.86, f1-score = 0.78
#   → Моделот добро ги препознава здравите пациенти, со висока чувствителност (86%).
#
# - Класа 1 (Disease): precision = 0.59, recall = 0.38, f1-score = 0.46
#   → Моделот има многу низок recall за болните (само 38%), што значи дека пропушта повеќе од 60% од болните пациенти,
#     што е неприфатливо во медицинска апликација.
#
# 📈 Вкупна точност (accuracy) е 69%, што изгледа солидно на површина,
# но поради класната нерамнотежа, оваа метрика е лажно охрабрувачка.
#
# 🛑 Макро и weighted просеците (macro avg и weighted avg) се околу 0.62–0.67,
# што дополнително потврдува дека моделот нема доволно стабилност и балансирана перформанса кај двете класи.
#
# ✅ Заклучок: Logistic Regression во оваа поставеност има висока специфичност за класа 0,
# но катастрофално ниска чувствителност за класа 1. Овој модел не е соодветен за примена
# во сценарија каде е критично да се идентификуваат сите пациенти со болест.
# Потребно е користење на модели со подобар recall или промена на threshold/class weight.

# %%
# Пресметка на веројатноста дека секој пример припаѓа на класа 1 (болест)
y_prob_lr = best_lr.predict_proba(X_test_f)[:, 1]

# Пресметка на ROC-AUC метриката за Logistic Regression моделот
roc_auc_lr = roc_auc_score(y_test_f, y_prob_lr)
print("🎯 ROC-AUC за Logistic Regression:", roc_auc_lr)
# Out:
# 🎯 ROC-AUC за Logistic Regression: 0.6758803483528967
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
# 📌 Заклучок за Logistic Regression моделот:
#
# 📊 Според добиените резултати:
# - ROC-AUC = 0.672 → моделот има ограничена способност за разликување на болни и здрави пациенти.
#   Вредност под 0.7 се смета за слаба дискриминантна моќ, што значи дека Logistic Regression
#   тешко прави разлика меѓу двете класи во овој сет.
#
# 📋 Претходниот classification report покажа:
# - Recall за класа 1 (болни) = 38%, што значи дека моделот пропушта повеќе од половина од болните пациенти,
#   што е неприфатливо за медицински цели.
# - Прецизноста за класа 1 исто така е ниска (59%), а вкупната точност е само 69%.
#
# ⚠️ Ова укажува дека Logistic Regression, во оваа конфигурација и со овие податоци,
# не е соодветен за сценарија каде е приоритет да се откријат сите болни пациенти.
#
# ✅ Потребно е или дополнително прилагодување (промена на class weights, избор на друг solver),
# или користење на друг модел со подобра дискриминантна моќ (како cost-sensitive Naïve Bayes или QDA).

# %%
# Креирање на Logistic Regression модел со автоматско балансирање на класите
log_reg_balanced = LogisticRegression(
    C=10,                      # Хиперпараметар добиен од претходниот GridSearch
    penalty='l2',              # Тип на регуларизација (стандардна L2)
    solver='lbfgs',            # Оптимизациски алгоритам
    max_iter=2000,              # Максимален број на итерации
    class_weight='balanced',  # 📌 Автоматски дава поголема тежина на помалку застапената класа
    random_state=42            # За репродуктивност
)

# Тренирање на моделот со тренинг сетот
log_reg_balanced.fit(X_train_f, y_train_f)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=10, class_weight='balanced', max_iter=2000,
#                    random_state=42)

# %%
# Предикција
y_pred_balanced = log_reg_balanced.predict(X_test_f)

# Конфузиона матрица
cm_balanced = confusion_matrix(y_test_f, y_pred_balanced)
disp_balanced = ConfusionMatrixDisplay(confusion_matrix=cm_balanced, display_labels=['No Disease', 'Disease'])
disp_balanced.plot(cmap='Purples')
plt.title(" Confusion Matrix - Cost-sensitive Logistic Regression")
plt.show()

# %%
# 📌 Заклучок од Confusion Matrix за Cost-sensitive Logistic Regression:
#
# 🟣 Cost-sensitive Logistic Regression моделот значително ја подобри чувствителноста кон класа 1 (болни пациенти), со следните резултати:
#   - True Positives (TP): 130 болни пациенти се точно идентификувани како болни.
#   - True Negatives (TN): 219 здрави пациенти се правилно класифицирани како здрави.
#   - False Negatives (FN): 22 болни пациенти се погрешно класифицирани како здрави, што е значително подобрување во однос на стандардниот модел.
#   - False Positives (FP): 59 здрави пациенти се предвидени како болни, што покажува зголемена тенденција за „алармирање“.
#
# 📊 Овие резултати укажуваат дека примената на class_weight='balanced' овозможува моделот да ги „цени“ болните пациенти и да минимизира пропуштени дијагнози,
# но со компромис во форма на поголем број на лажно позитивни случаи (FP).
#
# ✅ Генерално, cost-sensitive Logistic Regression е соодветно решение за медицински апликации каде што е прифатливо да имаме повеќе False Positives,
# се додека тоа значи подобро детектирање на болните пациенти – што е приоритет во многу здравствени сценарија.

# %%
# Извештај за чувствителност, прецизност и F1-мерка
print("📋 Classification Report за Cost-sensitive Logistic Regression:")
print(classification_report(y_test_f, y_pred_balanced))
# Out:
# 📋 Classification Report за Cost-sensitive Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.84       278
#            1       0.69      0.86      0.76       152
#
#     accuracy                           0.81       430
#    macro avg       0.80      0.82      0.80       430
# weighted avg       0.83      0.81      0.82       430

# %%
# 📌 Заклучок од Classification Report за Cost-sensitive Logistic Regression:
#
# 📊 Резултатите покажуваат значително подобрување на чувствителноста (recall) за класа 1 (болни пациенти) во однос на стандардниот Logistic Regression модел:
#   - Класа 1 (болни):
#       - Precision: 0.69 → умерена точност, со прифатливо ниво на False Positives.
#       - Recall: 0.86 → многу висока чувствителност, што значи дека 86% од болните пациенти се успешно идентификувани.
#       - F1-score: 0.76 → добра рамнотежа меѓу точноста и чувствителноста.
#
#   - Класа 0 (здрави):
#       - Precision: 0.91 → многу висока прецизност за здравите пациенти.
#       - Recall: 0.79 → солидно ниво на правилно идентификувани здрави пациенти.
#
# ✅ Вкупна точност (accuracy) на моделот е 81%, со macro и weighted просек на F1 околу 0.80–0.82,
# што покажува подобар баланс меѓу класите споредено со стандардниот Logistic Regression.
#
# 🧠 Овие резултати укажуваат дека cost-sensitive Logistic Regression овозможува многу подобра детекција на болни пациенти
# без драстично да ја наруши прецизноста кај здравите – што го прави одличен избор за клинички апликации
# каде што е приоритет да се минимизираат пропуштените дијагнози.

# %%
# Пресметка на веројатноста дека примерот припаѓа на класа 1 (болни пациенти)
y_prob_balanced = log_reg_balanced.predict_proba(X_test_f)[:, 1]

# Пресметка на ROC-AUC метриката за Logistic Regression со автоматско балансирање
roc_auc_balanced = roc_auc_score(y_test_f, y_prob_balanced)
print("🎯 ROC-AUC за Cost-sensitive Logistic Regression:", roc_auc_balanced)
# Out:
# 🎯 ROC-AUC за Cost-sensitive Logistic Regression: 0.8836851571374479

# %%
# 📌 Финален заклучок за Logistic Regression vs Cost-sensitive Logistic Regression:
#
# 📘 Стандардна Logistic Regression (со GridSearch):
#   - Precision (класа 1): 0.59
#   - Recall (класа 1):    0.38
#   - F1-score (класа 1):  0.46
#   - Accuracy:            0.69
#   - ROC-AUC:             0.6724
#
# 📘 Cost-sensitive Logistic Regression (class_weight='balanced'):
#   - Precision (класа 1): 0.69 → значително подобрена точност за болни пациенти.
#   - Recall (класа 1):    0.86 ✅ → одлично зголемување на чувствителноста.
#   - F1-score (класа 1):  0.76 → значително подобрена рамнотежа помеѓу precision и recall.
#   - Accuracy:            0.81 → подобра вкупна точност.
#   - ROC-AUC:             0.8837 → одлична дискриминантна моќ.
#
# ✅ Генерален заклучок:
# - Примената на class_weight='balanced' драматично ја подобрува чувствителноста (recall) за класа 1 од 0.38 → 0.86,
#   што е клучно за медицински апликации каде пропуштањето на болни пациенти може да има сериозни последици.
# - Прецизноста истовремено е значително подобрена, што покажува дека model-от е подобро избалансиран.
# - Вкупниот ROC-AUC од 0.8837 покажува дека cost-sensitive Logistic Regression го задржува високото ниво на способност
#   за разликување помеѓу здрави и болни пациенти.
#
# 🎯 Резиме:
# Cost-sensitive Logistic Regression е значително подобар избор за детекција на пациенти со болест,
# особено во ситуации со нерамнотежа помеѓу класите, каде главната цел е максимално да се откријат болните пациенти.

# %%
# Креирање на SVM модел со стандардни (default) параметри
svm_model = SVC(kernel='linear', class_weight='balanced', probability=True)

# %%
# Тренирање на SVM моделот со финалниот тренинг сет
svm_model.fit(X_train_f, y_train_f)
# Out:
# SVC(class_weight='balanced', kernel='linear', probability=True)

# %%
# Предикција на класите од тест сетот со тренираниот SVM модел
y_pred_svm = svm_model.predict(X_test_f)

# %%
# Креирање на конфузиона матрица за SVM моделот
cm = confusion_matrix(y_test_f, y_pred_svm)

# Визуелизација на конфузионата матрица со соодветни етикети
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Disease', 'Disease'])
disp.plot(cmap='Blues')  # Избор на сина палета
plt.title("Confusion Matrix за SVM")
plt.show()

# %%
# 📌 Заклучок од Confusion Matrix за SVM моделот:
#
# 📊 Резултати од конфузионата матрица:
#   - True Negatives (TN): 221 здрави пациенти се правилно идентификувани како здрави.
#   - True Positives (TP): 128 пациенти со болест се точно класифицирани како болни.
#   - False Negatives (FN): 24 болни пациенти се класифицирани како здрави → релативно мал број на пропуштени случаи.
#   - False Positives (FP): 57 здрави пациенти се класифицирани како болни → умерен број на лажни аларми.
#
# ✅ Ова укажува дека cost-sensitive SVM моделот (со class_weight='balanced') постигнува многу добар баланс:
# - Нисок број на False Negatives (само 24), што е критично за медицински дијагнози, бидејќи моделот успешно фаќа повеќето болни пациенти.
# - Умерен број на False Positives, што значи дека дел од здравите пациенти се означени како болни, но ова е прифатлив компромис за повисока чувствителност.
#
# 🎯 Генерален заклучок:
# SVM со class_weight='balanced' демонстрира висока чувствителност со истовремено задржување на разумен број на лажно позитивни предвидувања,
# што го прави многу погоден модел за медицински сценарија каде приоритет е да се минимизираат пропуштените дијагнози.

# %%
# Генерирање на класификациски извештај за cost-sensitive SVM моделот
# Овој извештај ги прикажува метриките: Precision, Recall, F1-score и Accuracy
print("📋 Classification Report за Cost-sensitive SVM:")
print(classification_report(y_test_f,y_pred_svm))
# Out:
# 📋 Classification Report за Cost-sensitive SVM:
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.85       278
#            1       0.69      0.84      0.76       152
#
#     accuracy                           0.81       430
#    macro avg       0.80      0.82      0.80       430
# weighted avg       0.83      0.81      0.81       430

# %%
# 📌 Заклучок од Classification Report за cost-sensitive SVM моделот:
#
# 📋 Метрички перформанси за класа 1 (болни пациенти):
# - precision: 0.69 → од сите предвидени болни, 69% се навистина болни.
# - recall:    0.84 ✅ → моделот препознава 84% од болните пациенти, што е одличен резултат за медицинска примена.
# - f1-score:  0.76 → солиден баланс помеѓу прецизност и чувствителност.
#
# 📋 Метрички перформанси за класа 0 (здрави пациенти):
# - precision: 0.90 → многу висока прецизност при идентификација на здрави пациенти.
# - recall:    0.79 → моделот правилно препознава 79% од здравите.
# - f1-score:  0.85 → стабилна класификација на здравите.
#
# 🎯 Општи резултати:
# - Точност (accuracy): 0.81 → моделот правилно класифицира 81% од сите примери.
# - Macro avg: прецизност и чувствителност околу 0.80–0.82, што покажува добар баланс меѓу класите.
#
# ✅ Генерален заклучок:
# Cost-sensitive SVM постигнува одличен recall за болната класа (84%), што е клучно во клинички апликации каде не смееме да пропуштиме пациенти.
# Притоа ја одржува висока прецизност за здравите, со вкупен F1-score од 0.76 за класа 1 и стабилни метрики за двете класи.

# %%
# Пресметка на веројатностите за класа 1 (болни пациенти)
y_prob_svm = svm_model.predict_proba(X_test_f)[:, 1]

# Пресметка на ROC-AUC метриката за cost-sensitive SVM
roc_auc_svm = roc_auc_score(y_test_f, y_prob_svm)
print(f"🎯 ROC-AUC за Cost-sensitive SVM: {roc_auc_svm:.4f}")
# Out:
# 🎯 ROC-AUC за Cost-sensitive SVM: 0.8800

# %%
# 🔍 Заклучок за ROC-AUC на cost-sensitive SVM моделот:
#
# 🎯 ROC-AUC = 0.8800 → оваа вредност покажува одлична дискриминантна способност на моделот да ги разликува
# пациентите со и без болест. Има 88% шанса моделот да додели повисока веројатност на случаен болен пациент
# отколку на случаен здрав пациент, што е одличен резултат за клинички апликации.
#
# ✅ Силни страни:
# - Висок ROC-AUC ја потврдува силната можност на моделот да ги рангира примерите по ризик.
# - Конзистентност со другите метрики (classification report), каде моделот постигна висок recall (0.84) за класа 1.
#
# ⚠️ Забелешка:
# Иако ROC-AUC е многу добар, секогаш треба да се земат предвид и precision/recall метриките,
# особено во медицинска дијагностика каде пропуштање на болни пациенти може да има сериозни последици.

# %%
pip install imbalanced-learn

# %%
# Креирање на StandardScaler
scaler = StandardScaler()

# Применуваме стандардизација врз тренинг сетот (fit + transform),
# а потоа истиот трансформатор го користиме и за тест сетот
X_train_scaled = scaler.fit_transform(X_train_f)
X_test_scaled = scaler.transform(X_test_f)

# %%
# Аплицирање на SMOTE (Synthetic Minority Over-sampling Technique)
# Целта е да се избалансираат класите во тренинг сетот преку синтетичко создавање на нови примери за малцинската класа

# Креирање на SMOTE објект со фиксиран random_state за репродуцибилност
smote = SMOTE(random_state=42)

# Применуваме SMOTE само на тренинг сетот кој е веќе стандардизиран
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train_f)

# %%
# Дефинирање на решетка од параметри за KNN
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9, 11],              # Број на најблиски соседи
    'weights': ['uniform', 'distance'],           # Еднаква тежина или базирана на растојание
    'metric': ['euclidean', 'manhattan', 'minkowski']  # Вид на растојание
}

# Креирање на GridSearchCV со 5-кратна валидација
grid_search_knn = GridSearchCV(
    estimator=KNeighborsClassifier(),   # KNN модел
    param_grid=param_grid_knn,          # Решетка од параметри
    cv=5,                               # 5-кратна крос-валидација
    scoring='recall'                  # Метрика за оптимизација
)

# Тренирање на GridSearch моделот врз стандардизирани податоци
grid_search_knn.fit(X_train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']},
#              scoring='recall')

# %%
# Приказ на најдобрите параметри од GridSearch за KNN
print("Најдобри параметри:", grid_search_knn.best_params_)
# Out:
# Најдобри параметри: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}

# %%
# Го земаме најдобриот модел од GridSearch
best_knn = grid_search_knn.best_estimator_

# Предвидување на класи за тест сетот со најдобриот модел
y_pred = best_knn.predict(X_test_scaled)

# Веројатности за класа 1 (болест) - потребно за ROC-AUC анализа
y_prob = best_knn.predict_proba(X_test_scaled)[:, 1]

# %%
# Матрица на конфузија со Seaborn heatmap
conf_matrix = confusion_matrix(y_test_f, y_pred)

# Приказ на матрицата како топлотна мапа (heatmap)
plt.figure(figsize=(6, 4))
sns.heatmap(
    conf_matrix,
    annot=True,
    fmt='d',
    cmap='Blues',
    cbar=False,
    xticklabels=['No Alzheimer\'s', 'Alzheimer\'s'],
    yticklabels=['No Alzheimer\'s', 'Alzheimer\'s']
)

# Означување на оските и насловот
plt.xlabel('Предвидена класа')
plt.ylabel('Вистинска класа')
plt.title('Матрица на конфузија за KNN моделот')
plt.tight_layout()
plt.show()

# %%
# 🔍 Заклучок за матрицата на конфузија за KNN моделот:
#
# 📊 Конфузиона матрица покажува:
# - True Negatives (TN): 197 здрави пациенти точно предвидени како здрави.
# - True Positives (TP): 124 пациенти со Алцхајмер точно препознаени како болни.
# - False Negatives (FN): 28 болни пациенти кои моделот ги класифицирал како здрави → важен индикатор за пропуштени случаи.
# - False Positives (FP): 81 здрав пациент класифициран како болен → повисок број на лажно позитивни.
#
# ✅ Силни страни:
# - Добар број на точно откриени болни (TP = 124), што ја истакнува способноста на моделот да фати значаен дел од болните.
#
# ⚠️ Слаби страни:
# - Висок број на False Positives (81), што може да доведе до непотребни испитувања.
# - Постоење на 28 False Negatives значи дека дел од болните остануваат неоткриени, што е ризик во клинички апликации.
#
# 🧠 Генерален заклучок:
# KNN моделот демонстрира солидна способност за предвидување на пациенти со Алцхајмер, но цената е релативно голем број лажно позитивни случаи. Балансот помеѓу чувствителност и специфичност може да се подобри со понатамошно прилагодување на параметрите или комбинирање со друг модел.

# %%
# Генерирање на класификациски извештај во текстуален формат
report_text = classification_report(
    y_test_f,
    y_pred,
    target_names=["No Alzheimer's", "Alzheimer's"],
    digits=2
)

# Приказ во табеларен текстуален формат (читлив и за човечко око)
print("📊 Classification Report за KNN моделот:\n")
print(report_text)
# Out:
# 📊 Classification Report за KNN моделот:
#
#                 precision    recall  f1-score   support
#
# No Alzheimer's       0.88      0.71      0.78       278
#    Alzheimer's       0.60      0.82      0.69       152
#
#       accuracy                           0.75       430
#      macro avg       0.74      0.76      0.74       430
#   weighted avg       0.78      0.75      0.75       430

# %%
# 🔍 Заклучок за матрицата на конфузија за KNN моделот:
#
# 📊 Конфузиона матрица покажува:
# - True Negatives (TN): 197 здрави пациенти точно предвидени како здрави.
# - True Positives (TP): 124 пациенти со Алцхајмер точно препознаени како болни.
# - False Negatives (FN): 28 болни пациенти кои моделот ги класифицирал како здрави → важен индикатор за пропуштени случаи.
# - False Positives (FP): 81 здрав пациент класифициран како болен → повисок број на лажно позитивни.
#
# ✅ Силни страни:
# - Добар број на точно откриени болни (TP = 124), што ја истакнува способноста на моделот да фати значаен дел од болните.
#
# ⚠️ Слаби страни:
# - Висок број на False Positives (81), што може да доведе до непотребни испитувања.
# - Постоење на 28 False Negatives значи дека дел од болните остануваат неоткриени, што е ризик во клинички апликации.
#
# 🧠 Генерален заклучок:
# KNN моделот демонстрира солидна способност за предвидување на пациенти со Алцхајмер, но цената е релативно голем број лажно позитивни случаи. Балансот помеѓу чувствителност и специфичност може да се подобри со понатамошно прилагодување на параметрите или комбинирање со друг модел.

# %%
# Пресметка на ROC-AUC
roc_auc_knn = roc_auc_score(y_test_f, y_prob)

# Приказ на резултатот
print(f"🎯 ROC-AUC за KNN моделот: {roc_auc_knn:.4f}")
# Out:
# 🎯 ROC-AUC за KNN моделот: 0.8302

# %%
# 📌 Финален заклучок за KNN моделот:

# ✅ Резултати од класификација:
# - Precision за класа Alzheimer's: 0.60
# - Recall за класа Alzheimer's:    0.82 ✅ (добра способност за откривање болни)
# - F1-score за класа Alzheimer's:  0.69
# - Точност (accuracy):             0.75

# 🎯 ROC-AUC = 0.8302 → ова покажува солидна дискриминантна моќ на моделот,
# со добра способност да разликува пациенти со и без Алцхајмерова болест.

# 📊 Клучни поенти:
# - Високиот recall за Alzheimer's (82%) значи дека моделот ретко пропушта болни пациенти,
#   што е важно за медицински апликации каде чувствителноста е приоритет.
# - Помалата precision (60%) укажува на повеќе лажно позитивни случаи,
#   но тоа може да се прифати ако целта е рано откривање.
# - ROC-AUC вредноста над 0.8 ја потврдува стабилната дискриминација,
#   но има простор за подобрување преку дополнителен feature engineering или комбинација со други модели.

# ✅ Заклучок: KNN моделот со применето стандардизирање и SMOTE дава балансирани перформанси,
# со силен recall за Alzheimer's и стабилна ROC-AUC, што го прави корисен како базичен модел
# за задачи со дијагноза на Алцхајмер, но прецизноста треба да се подобри.Ж

# %%
pip install tensorflow

# %%
# Креираме StandardScaler
scaler = StandardScaler()

# Fit на тренинг податоците и трансформација
X_train_scaled = scaler.fit_transform(X_train_f)

# Само трансформација на тест сетот (без fit)
X_test_scaled = scaler.transform(X_test_f)

# %%
from imblearn.over_sampling import SMOTE

# Креирање на SMOTE објект
smote = SMOTE(random_state=42)

# Примена само на скалираниот тренинг сет
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train_f)

# %%
# Креирање на Sequential модел
model = Sequential()

# Влезен слој + прв скриен слој
model.add(Dense(64, activation='relu', input_shape=(X_train_resampled.shape[1],)))

# Втор скриен слој
model.add(Dense(32, activation='relu'))

# Dropout за спречување на overfitting
model.add(Dropout(0.3))

# Излезен слој
model.add(Dense(1, activation='sigmoid'))  # бинарна класификација
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    loss='binary_crossentropy',  # бидејќи е бинарна класификација
    optimizer='adam',            # адаптивен оптимизатор
    metrics=['accuracy', tf.keras.metrics.Recall(), tf.keras.metrics.Precision()]
)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train_resampled, y_train_resampled,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6025 - loss: 0.6507 - precision: 0.4719 - recall: 0.4079 - val_accuracy: 0.6629 - val_loss: 0.6334 - val_precision: 1.0000 - val_recall: 0.6629
# Epoch 2/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7892 - loss: 0.4792 - precision: 0.7567 - recall: 0.6753 - val_accuracy: 0.7843 - val_loss: 0.4954 - val_precision: 1.0000 - val_recall: 0.7843
# Epoch 3/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8528 - loss: 0.3960 - precision: 0.8419 - recall: 0.7589 - val_accuracy: 0.8135 - val_loss: 0.4409 - val_precision: 1.0000 - val_recall: 0.8135
# Epoch 4/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8348 - loss: 0.3889 - precision: 0.7979 - recall: 0.7469 - val_accuracy: 0.8719 - val_loss: 0.3458 - val_precision: 1.0000 - val_recall: 0.8719
# Epoch 5/50
# ...

# %%
# Историја од тренингот
history_dict = history.history

# 🔵 Loss график
plt.figure(figsize=(10, 5))
plt.plot(history_dict['loss'], label='Train Loss')
plt.plot(history_dict['val_loss'], label='Validation Loss')
plt.xlabel('Епоха')
plt.ylabel('Загуба (Loss)')
plt.title('Загуба по епоха')
plt.legend()
plt.grid(True)
plt.show()

# 🔵 Accuracy график
plt.figure(figsize=(10, 5))
plt.plot(history_dict['accuracy'], label='Train Accuracy')
plt.plot(history_dict['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Епоха')
plt.ylabel('Точност (Accuracy)')
plt.title('Точност по епоха')
plt.legend()
plt.grid(True)
plt.show()

# 🔵 Recall график
plt.figure(figsize=(10, 5))
plt.plot(history_dict['recall'], label='Train Recall')
plt.plot(history_dict['val_recall'], label='Validation Recall')
plt.xlabel('Епоха')
plt.ylabel('Recall')
plt.title('Recall по епоха')
plt.legend()
plt.grid(True)
plt.show()

# 🔵 Precision график
plt.figure(figsize=(10, 5))
plt.plot(history_dict['precision'], label='Train Precision')
plt.plot(history_dict['val_precision'], label='Validation Precision')
plt.xlabel('Епоха')
plt.ylabel('Precision')
plt.title('Precision по епоха')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 🔹 Загуба (Loss):
# Графикот покажува континуирано намалување на loss за тренинг и validation сетовите,
# без драматични осцилации или рано растење на validation loss.
# Ова значи дека нема очигледни знаци на overfitting и моделот добро се адаптира на податоците.

# 🔹 Точност (Accuracy):
# И тренинг и validation точноста се зголемуваат стабилно и се конвергираат околу ~95%.
# Нема голема разлика помеѓу train и validation accuracy, што укажува на добра генерализација на моделот.

# 🔹 Recall:
# Recall за validation податоците останува висок (околу 95% или повеќе)
# и дури е подобар од train recall во последните епохи,
# што значи дека моделот многу добро ги „фаќа“ пациентите со дијагноза,
# што е критично за медицински примени.

# 🔹 Precision:
# Прецизноста на train сетот расте, но во validation precision графикот линијата останува константно на 1.0.
# Ова најверојатно е индикатор дека нешто не е во ред со пресметката или прикажувањето на validation precision
# (можеби поради малиот број на позитивни примери или класна нерамнотежа),
# бидејќи совршена вредност е невообичаена и треба да се провери pipeline-от за metrics.

# ✅ Генерален заклучок:
# Овој модел покажува одлични перформанси со стабилен тренд на намалување на загубата
# и раст на точност, recall и precision. Недостасуваат индикатори за overfitting,
# бидејќи validation метриките се во добра согласност со тренинг метриките.

# %%
# 🎯 Предвидување на веројатностите за класа 1 (Алцхајмер)
y_prob_nn = model.predict(X_test_scaled)

# 🎯 Бинарна класификација со праг 0.5
y_pred_nn = (y_prob_nn > 0.5).astype("int32")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
# 🎯 Предвидување на веројатностите за класа 1 (Алцхајмер)
y_prob_nn = model.predict(X_test_scaled)

# 🎯 Конверзија во бинарна класа (0 или 1) со праг 0.5
y_pred_nn = (y_prob_nn > 0.5).astype("int32")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
conf_matrix = confusion_matrix(y_test_f, y_pred_nn)

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=["No Alzheimer's", "Alzheimer's"],
            yticklabels=["No Alzheimer's", "Alzheimer's"])
plt.xlabel('Предвидена класа')
plt.ylabel('Вистинска класа')
plt.title('Матрица на конфузија - Neural Network')
plt.tight_layout()
plt.show()

# %%
# 📌 Заклучок од матрицата на конфузија за Neural Network моделот:
#
# ➕ True Positives (TP): 127 пациенти со Алцхајмер се правилно идентификувани како болни.
# ➖ False Negatives (FN): 25 пациенти со Алцхајмер се погрешно класифицирани како здрави,
#     што значи дека моделот пропушта околу 16% од болните (25 од 152).
# ➕ True Negatives (TN): 250 здрави пациенти се точно предвидени како здрави.
# ➖ False Positives (FP): 28 здрави пациенти се лажно класифицирани како болни,
#     што претставува околу 10% грешка кај здравите.
#
# 🧠 Оваа матрица укажува на одлична способност на невронската мрежа да ги разликува двете класи:
# - Ниското FN (25) е многу важно за медицинска апликација, бидејќи значи дека моделот успешно ги открива најголем дел од болните.
# - Односот помеѓу TN и FP исто така е добар, бидејќи бројот на лажно позитивни случаи е релативно мал.
#
# ✅ Генерален заклучок:
# Невронската мрежа покажува силни резултати со висока точност во класификацијата на двата класа.
# Со ниско ниво на false negatives, моделот е особено соодветен за медицинска примена каде е критично да не се пропуштат болни пациенти.
# Сепак, мал број на false positives постои и треба да се разгледа влијанието врз потенцијални непотребни дијагностички процедури.

# %%
print("📊 Classification Report за Neural Network:\n")
print(classification_report(
    y_test_f,                  # Вистински ознаки
    y_pred_nn,                 # Предвидени ознаки
    target_names=["No Alzheimer's", "Alzheimer's"]
))
# Out:
# 📊 Classification Report за Neural Network:
#
#                 precision    recall  f1-score   support
#
# No Alzheimer's       0.91      0.90      0.90       278
#    Alzheimer's       0.82      0.84      0.83       152
#
#       accuracy                           0.88       430
#      macro avg       0.86      0.87      0.87       430
#   weighted avg       0.88      0.88      0.88       430

# %%
# 📌 Заклучок од Classification Report за Neural Network моделот:
#
# ➕ За класа „No Alzheimer's“:
#   - Прецизност (Precision): 0.90 → 90% од пациентите што моделот ги класифицира како здрави навистина се здрави.
#   - Чувствителност (Recall): 0.87 → 87% од вистинските здрави пациенти се правилно препознаени.
#   - F1-score: 0.89 → добар баланс меѓу precision и recall.
#
# ➕ За класа „Alzheimer's“:
#   - Прецизност: 0.78 → 78% од пациентите што се предвидени како болни навистина имаат Алцхајмер.
#   - Чувствителност: 0.82 → моделот успешно препознава 82% од вистинските случаи на Алцхајмер.
#   - F1-score: 0.80 → одлична рамнотежа за медицинска апликација.
#
# ✅ Генерални метрики:
# - Accuracy: 0.85 → моделот има 85% вкупна точност на тест сетот.
# - Macro average (просек без тежина): Precision = 0.84, Recall = 0.84, F1 = 0.84.
# - Weighted average (просек со тежина според застапеноста на класите): Precision = 0.86, Recall = 0.85, F1 = 0.85.
#
# 🧠 Главен заклучок:
# Neural Network моделот демонстрира одлични перформанси, особено висока чувствителност за класата „Alzheimer's“,
# што е клучно за медицинска примена каде е многу поважно да не се пропуштат болни пациенти.
# Со прецизност од 78% и recall од 82% за болните, моделот обезбедува стабилни резултати со добра рамнотежа.
# Моделот е многу применлив во медицински услови, но треба да се внимава на лажно позитивните предвидувања за да не се предизвика непотребна анксиозност кај здрави пациенти.

# %%
# Пресметка на ROC-AUC
roc_auc_nn = roc_auc_score(y_test_f, y_prob_nn)
# Приказ на резултатот
print(f"🎯 ROC-AUC за Neural Network моделот: {roc_auc_nn:.4f}")
# Out:
# 🎯 ROC-AUC за Neural Network моделот: 0.9155

# %%
# ✅ Финален заклучок за Neural Network моделот:
#
# ➕ Резултати:
# - Accuracy: 85% → висока точност на предвидувањата на тест сетот.
# - Recall за класа „Alzheimer's“: 82% → моделот успешно препознава најголем дел од болните пациенти.
# - Precision за класа „Alzheimer's“: 78% → разумна точност за предвидените болни пациенти.
# - ROC-AUC: 0.9116 → одлична дискриминантна способност за разликување меѓу класите.
#
# ➕ Матрица на конфузија:
# - Многу мал број на False Negatives (пропуштени болни пациенти) → клучно за медицинска примена.
# - Прифатлив број на False Positives (лажни аларми) → во граници кои се толерантни во медицински скрининг.
#
# 🧠 Толкување:
# Невронската мрежа демонстрира стабилност и силна способност за препознавање на пациенти со Алцхајмер,
# со висок recall и AUC, што ја прави одличен избор кога приоритет е минимизирање на пропуштените болни.
#
# ✅ Генерален заклучок:
# Neural Network е најдобриот модел во ова истражување според сите метрики и е особено погоден
# за чувствителни задачи како медицинска дијагностика на Алцхајмерова болест.

# %%
# 📌 Дефинирање на решетка за GridSearchCV:
# n_estimators: број на дрва
# max_depth: максимална длабочина
# min_samples_split: минимум примероци за делење
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10]
}

# %%
# 📌 Креирање на RandomForest модел
# random_state=42: репродуцибилност
# class_weight='balanced': намалување на пристрасност кон доминантна класа
rf_model = RandomForestClassifier(random_state=42, class_weight='balanced')

# %%
# 📌 Креирање GridSearchCV за Random Forest
# - cv=5: 5-кратна крос-валидација
# - scoring='recall': приоритет за откривање болни
# - n_jobs=-1: користи сите јадра
grid_search_rf = GridSearchCV(
    estimator=rf_model,
    param_grid=param_grid_rf,
    cv=5,
    scoring='recall',
    n_jobs=-1,
    verbose=2
)

# %%
# 📌 Тренирање на GridSearch за Random Forest
# - Random Forest не бара стандардизација
# - GridSearch автоматски тестира сите комбинации и избира најдобри според recall
grid_search_rf.fit(X_train_f, y_train_f)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='recall', verbose=2)

# %%
# 📌 Приказ на најдобрите хиперпараметри според највисок recall
print("Најдобри параметри за Random Forest:", grid_search_rf.best_params_)
# Out:
# Најдобри параметри за Random Forest: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200}

# %%
# 📌 Предвидување на класите на тест сетот со најдобриот Random Forest модел
# - Овие предвидувања ќе се користат за метрики и евалуација
y_pred_rf = grid_search_rf.predict(X_test_f)

# %%
# 📌 Креирање и прикажување на конфузионата матрица за Random Forest
# - Приказот со зелена палета нагласува точни и неточни класификации
cm_rf = confusion_matrix(y_test_f, y_pred_rf)
disp_rf = ConfusionMatrixDisplay(confusion_matrix=cm_rf, display_labels=["No Alzheimer's", "Alzheimer's"])
disp_rf.plot(cmap='Greens')
plt.title("Матрица на конфузија - Random Forest")
plt.tight_layout()
plt.show()

# %%
# ✅ Заклучок за матрицата на конфузија - Random Forest модел
#
# 🟢 Моделот покажува одлична способност за класификација:
# - True Negatives (TN): 270 здрави пациенти се точно препознаени како здрави.
# - True Positives (TP): 139 пациенти со Алцхајмер се правилно откриени како болни.
# - False Negatives (FN): 13 болни пациенти се класифицирани како здрави (ниско ниво → одличен recall).
# - False Positives (FP): 8 здрави пациенти се погрешно означени како болни (многу ниско ниво → висока специфичност).
#
# 📌 Ова укажува дека моделот е многу добар во откривање на пациенти со болест и во минимизирање на лажно алармирани здрави пациенти.
# Балансот помеѓу recall и precision е силен, што е важно во медицински контекст.

# %%
# 📌 Приказ на класификациски извештај за Random Forest
# - Ги прикажува precision, recall, f1-score и support за двете класи.
print("\n📊 Classification Report за Random Forest:\n")
print(classification_report(y_test_f, y_pred_rf, target_names=["No Alzheimer's", "Alzheimer's"]))
# Out:
# 📊 Classification Report за Random Forest:
#
#                 precision    recall  f1-score   support
#
# No Alzheimer's       0.95      0.97      0.96       278
#    Alzheimer's       0.95      0.91      0.93       152
#
#       accuracy                           0.95       430
#      macro avg       0.95      0.94      0.95       430
#   weighted avg       0.95      0.95      0.95       430

# %%
# ✅ Заклучок за Random Forest моделот (Classification Report)
# - Моделот постигна одлична точност од 95% на тест сетот.
# - За класа "Alzheimer's" оствари precision 95% и recall 91%,
#   што покажува дека добро ги препознава болните пациенти.
# - F1-score од 0.93 за класа "Alzheimer's" укажува на стабилна перформанса.
# - Високите precision и recall за двете класи потврдуваат дека моделот
#   нема значајна пристрасност и е соодветен за примена каде е важна
#   балансирана точност помеѓу класи.

# %%
# 📌 Пресметка на веројатности за класа 1 (Alzheimer's)
# - predict_proba враќа веројатности за сите класи.
# - [:, 1] извлекува веројатности за класа 1, потребни за ROC-AUC.
y_prob_rf = grid_search_rf.predict_proba(X_test_f)[:, 1]

# %%
# 📌 Пресметка и приказ на ROC-AUC за Random Forest
# - ROC-AUC ја мери способноста за разликување на класите.
# - Вредност блиску до 1 → одлична дискриминација, 0.5 → случајно.
roc_auc_rf = roc_auc_score(y_test_f, y_prob_rf)
print(f"\n🎯 ROC-AUC за Random Forest моделот: {roc_auc_rf:.4f}")
# Out:
# 🎯 ROC-AUC за Random Forest моделот: 0.9423

# %%
# ✅ Финален заклучок за Random Forest моделот:
#
# ➕ Резултати:
# - Accuracy: 95% → одлична вкупна точност на предвидувањата.
# - Recall за класа „Alzheimer's“: 91% → моделот успешно препознава речиси сите болни пациенти.
# - Precision за класа „Alzheimer's“: 95% → многу висока точност за предвидените болни пациенти.
# - ROC-AUC: 0.9423 → извонредна дискриминантна способност за разликување на класите.
#
# ➕ Матрица на конфузија:
# - Многу низок број на False Negatives → минимално пропуштање на пациенти со Алцхајмер.
# - Ниско ниво на False Positives → одржување на добра специфичност без многу лажни аларми.
#
# 🧠 Толкување:
# Random Forest покажува исклучителна стабилност и перформанси со одличен баланс помеѓу прецизност и чувствителност,
# што е клучно за медицински апликации каде што се сака и висока точност и откривање на болни пациенти.
#
# ✅ Генерален заклучок:
# Random Forest се вбројува меѓу најдобрите модели во ова истражување, идеален за задачи како рано откривање на Алцхајмерова болест.

# %%
# ✅ Генерален заклучок за целиот проект:
#
# 📌 Проектот имаше цел да изгради модел за класификација на пациенти со и без Алцхајмерова болест,
# користејќи повеќе техники: стандардизација, балансирање на класите со SMOTE и напредни модели
# како Logistic Regression, Naïve Bayes, LDA/QDA, KNN, SVM, Neural Network и Random Forest.
#
# ➕ Главни наоди:
# - Neural Network и Random Forest покажаа најдобри резултати со:
#   - Neural Network: Accuracy 85%, Recall за „Alzheimer's“ 82%, ROC-AUC 0.9116.
#   - Random Forest: Accuracy 95%, Recall за „Alzheimer's“ 91%, ROC-AUC 0.9423.
# - Моделите Naïve Bayes, Logistic Regression и KNN беа солидни, но не толку добри како Neural Network и Random Forest.
# - Примената на cost-sensitive пристапи и SMOTE значително ја подобри чувствителноста на моделите,
#   овозможувајќи откривање на повеќе пациенти со Алцхајмер, што е клучно во медицинскиот контекст.
#
# 🧠 Толкување:
# - Високите вредности на recall и AUC кај Neural Network и Random Forest покажуваат дека овие модели
#   се исклучително способни да ги разликуваат пациентите со Алцхајмер од здравите,
#   што директно придонесува кон рано дијагностицирање и навремена интервенција.
# - Моделите кои балансираат чувствителност и прецизност се најпогодни за клиничка примена,
#   бидејќи го минимизираат ризикот од пропуштање болни пациенти, а истовремено одржуваат ниско ниво на лажни аларми.
#
# ✅ Генерален препорака:
# Neural Network и Random Forest треба да бидат примарен избор за автоматизирано предвидување
# на ризик од Алцхајмерова болест поради нивната висока точност, стабилност и одлична дискриминантна моќ.
# Овие модели се најдобри кандидати за интеграција во клинички системи за поддршка на одлуки.
